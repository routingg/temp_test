# %% [markdown]
# <a href="https://colab.research.google.com/github/routingg/temp_test/blob/main/Chap_12_Reinforced_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %matplotlib
# %matplotlib inline
import os
os.chdir('/content')

# !python Chap_12_Reinforced_Learning_Training.py
# Out:
# Using matplotlib backend: agg
# 2023-05-30 04:35:56.778741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-30 04:35:59.367782: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 트레이닝을 시작합니다.
# /content/Chap_12_Reinforced_Learning_Training.py:168: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f3a5c0b4280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0530 04:36:00.545571 139890961065792 polymorphic_function.py:156] 5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f3a5c0b4280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f3a5c0b4280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0530 04:36:00.614570 139890961065792 polymorphic_function.py:156] 6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f3a5c0b4280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 반복(Epoch): 0, 에러(err): 0.0211, 승리횟수(Win count): 1, 승리비율(Win ratio): 100.0000
# 반복(Epoch): 1, 에러(err): 0.0316, 승리횟수(Win count): 1, 승리비율(Win ratio): 50.0000
# /content/model.ckpt-1 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 2, 에러(err): 0.1905, 승리횟수(Win count): 2, 승리비율(Win ratio): 66.6667
# 반복(Epoch): 3, 에러(err): 0.2251, 승리횟수(Win count): 3, 승리비율(Win ratio): 75.0000
# 반복(Epoch): 4, 에러(err): 0.2425, 승리횟수(Win count): 3, 승리비율(Win ratio): 60.0000
# 반복(Epoch): 5, 에러(err): 0.4124, 승리횟수(Win count): 4, 승리비율(Win ratio): 66.6667
# 반복(Epoch): 6, 에러(err): 0.4146, 승리횟수(Win count): 4, 승리비율(Win ratio): 57.1429
# 반복(Epoch): 7, 에러(err): 0.3669, 승리횟수(Win count): 4, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 8, 에러(err): 0.4050, 승리횟수(Win count): 4, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 9, 에러(err): 0.3170, 승리횟수(Win count): 4, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 10, 에러(err): 0.6187, 승리횟수(Win count): 4, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 11, 에러(err): 0.5564, 승리횟수(Win count): 4, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 12, 에러(err): 0.5269, 승리횟수(Win count): 4, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 13, 에러(err): 0.4214, 승리횟수(Win count): 4, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 14, 에러(err): 0.3588, 승리횟수(Win count): 4, 승리비율(Win ratio): 26.6667
# 반복(Epoch): 15, 에러(err): 0.5225, 승리횟수(Win count): 4, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 16, 에러(err): 0.5295, 승리횟수(Win count): 4, 승리비율(Win ratio): 23.5294
# 반복(Epoch): 17, 에러(err): 0.3641, 승리횟수(Win count): 5, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 18, 에러(err): 0.4254, 승리횟수(Win count): 5, 승리비율(Win ratio): 26.3158
# 반복(Epoch): 19, 에러(err): 0.4805, 승리횟수(Win count): 5, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 20, 에러(err): 0.3359, 승리횟수(Win count): 5, 승리비율(Win ratio): 23.8095
# 반복(Epoch): 21, 에러(err): 0.4581, 승리횟수(Win count): 6, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 22, 에러(err): 0.3813, 승리횟수(Win count): 6, 승리비율(Win ratio): 26.0870
# 반복(Epoch): 23, 에러(err): 0.5132, 승리횟수(Win count): 6, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 24, 에러(err): 0.3577, 승리횟수(Win count): 7, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 25, 에러(err): 0.4380, 승리횟수(Win count): 7, 승리비율(Win ratio): 26.9231
# 반복(Epoch): 26, 에러(err): 0.3513, 승리횟수(Win count): 7, 승리비율(Win ratio): 25.9259
# 반복(Epoch): 27, 에러(err): 0.4110, 승리횟수(Win count): 7, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 28, 에러(err): 0.3899, 승리횟수(Win count): 7, 승리비율(Win ratio): 24.1379
# 반복(Epoch): 29, 에러(err): 0.3786, 승리횟수(Win count): 7, 승리비율(Win ratio): 23.3333
# 반복(Epoch): 30, 에러(err): 0.3500, 승리횟수(Win count): 7, 승리비율(Win ratio): 22.5806
# 반복(Epoch): 31, 에러(err): 0.4137, 승리횟수(Win count): 8, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 32, 에러(err): 0.3922, 승리횟수(Win count): 9, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 33, 에러(err): 0.3168, 승리횟수(Win count): 9, 승리비율(Win ratio): 26.4706
# 반복(Epoch): 34, 에러(err): 0.4157, 승리횟수(Win count): 10, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 35, 에러(err): 0.4371, 승리횟수(Win count): 10, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 36, 에러(err): 0.3886, 승리횟수(Win count): 10, 승리비율(Win ratio): 27.0270
# 반복(Epoch): 37, 에러(err): 0.3360, 승리횟수(Win count): 10, 승리비율(Win ratio): 26.3158
# 반복(Epoch): 38, 에러(err): 0.3030, 승리횟수(Win count): 10, 승리비율(Win ratio): 25.6410
# 반복(Epoch): 39, 에러(err): 0.3362, 승리횟수(Win count): 10, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 40, 에러(err): 0.3250, 승리횟수(Win count): 10, 승리비율(Win ratio): 24.3902
# 반복(Epoch): 41, 에러(err): 0.4046, 승리횟수(Win count): 11, 승리비율(Win ratio): 26.1905
# 반복(Epoch): 42, 에러(err): 0.2963, 승리횟수(Win count): 11, 승리비율(Win ratio): 25.5814
# 반복(Epoch): 43, 에러(err): 0.3587, 승리횟수(Win count): 12, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 44, 에러(err): 0.4183, 승리횟수(Win count): 12, 승리비율(Win ratio): 26.6667
# 반복(Epoch): 45, 에러(err): 0.3533, 승리횟수(Win count): 12, 승리비율(Win ratio): 26.0870
# 반복(Epoch): 46, 에러(err): 0.2467, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.6596
# 반복(Epoch): 47, 에러(err): 0.3808, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.0833
# 반복(Epoch): 48, 에러(err): 0.2924, 승리횟수(Win count): 13, 승리비율(Win ratio): 26.5306
# 반복(Epoch): 49, 에러(err): 0.2366, 승리횟수(Win count): 13, 승리비율(Win ratio): 26.0000
# 반복(Epoch): 50, 에러(err): 0.2656, 승리횟수(Win count): 13, 승리비율(Win ratio): 25.4902
# 반복(Epoch): 51, 에러(err): 0.2969, 승리횟수(Win count): 13, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 52, 에러(err): 0.3120, 승리횟수(Win count): 13, 승리비율(Win ratio): 24.5283
# 반복(Epoch): 53, 에러(err): 0.2509, 승리횟수(Win count): 13, 승리비율(Win ratio): 24.0741
# 반복(Epoch): 54, 에러(err): 0.2533, 승리횟수(Win count): 13, 승리비율(Win ratio): 23.6364
# 반복(Epoch): 55, 에러(err): 0.3672, 승리횟수(Win count): 13, 승리비율(Win ratio): 23.2143
# 반복(Epoch): 56, 에러(err): 0.3028, 승리횟수(Win count): 14, 승리비율(Win ratio): 24.5614
# 반복(Epoch): 57, 에러(err): 0.2281, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.8621
# 반복(Epoch): 58, 에러(err): 0.2874, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.4237
# 반복(Epoch): 59, 에러(err): 0.2400, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 60, 에러(err): 0.2539, 승리횟수(Win count): 15, 승리비율(Win ratio): 24.5902
# 반복(Epoch): 61, 에러(err): 0.2631, 승리횟수(Win count): 15, 승리비율(Win ratio): 24.1935
# 반복(Epoch): 62, 에러(err): 0.2450, 승리횟수(Win count): 15, 승리비율(Win ratio): 23.8095
# 반복(Epoch): 63, 에러(err): 0.2222, 승리횟수(Win count): 15, 승리비율(Win ratio): 23.4375
# 반복(Epoch): 64, 에러(err): 0.2618, 승리횟수(Win count): 16, 승리비율(Win ratio): 24.6154
# 반복(Epoch): 65, 에러(err): 0.2413, 승리횟수(Win count): 16, 승리비율(Win ratio): 24.2424
# 반복(Epoch): 66, 에러(err): 0.3018, 승리횟수(Win count): 16, 승리비율(Win ratio): 23.8806
# 반복(Epoch): 67, 에러(err): 0.2489, 승리횟수(Win count): 17, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 68, 에러(err): 0.2865, 승리횟수(Win count): 17, 승리비율(Win ratio): 24.6377
# 반복(Epoch): 69, 에러(err): 0.2503, 승리횟수(Win count): 17, 승리비율(Win ratio): 24.2857
# 반복(Epoch): 70, 에러(err): 0.2600, 승리횟수(Win count): 17, 승리비율(Win ratio): 23.9437
# 반복(Epoch): 71, 에러(err): 0.2050, 승리횟수(Win count): 18, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 72, 에러(err): 0.3286, 승리횟수(Win count): 18, 승리비율(Win ratio): 24.6575
# 반복(Epoch): 73, 에러(err): 0.2865, 승리횟수(Win count): 19, 승리비율(Win ratio): 25.6757
# 반복(Epoch): 74, 에러(err): 0.2085, 승리횟수(Win count): 20, 승리비율(Win ratio): 26.6667
# 반복(Epoch): 75, 에러(err): 0.2264, 승리횟수(Win count): 20, 승리비율(Win ratio): 26.3158
# 반복(Epoch): 76, 에러(err): 0.2693, 승리횟수(Win count): 20, 승리비율(Win ratio): 25.9740
# 반복(Epoch): 77, 에러(err): 0.2113, 승리횟수(Win count): 20, 승리비율(Win ratio): 25.6410
# 반복(Epoch): 78, 에러(err): 0.2363, 승리횟수(Win count): 20, 승리비율(Win ratio): 25.3165
# 반복(Epoch): 79, 에러(err): 0.2791, 승리횟수(Win count): 20, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 80, 에러(err): 0.2598, 승리횟수(Win count): 20, 승리비율(Win ratio): 24.6914
# 반복(Epoch): 81, 에러(err): 0.2084, 승리횟수(Win count): 20, 승리비율(Win ratio): 24.3902
# 반복(Epoch): 82, 에러(err): 0.2130, 승리횟수(Win count): 20, 승리비율(Win ratio): 24.0964
# 반복(Epoch): 83, 에러(err): 0.2696, 승리횟수(Win count): 21, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 84, 에러(err): 0.2055, 승리횟수(Win count): 21, 승리비율(Win ratio): 24.7059
# 반복(Epoch): 85, 에러(err): 0.2666, 승리횟수(Win count): 21, 승리비율(Win ratio): 24.4186
# 반복(Epoch): 86, 에러(err): 0.2433, 승리횟수(Win count): 21, 승리비율(Win ratio): 24.1379
# 반복(Epoch): 87, 에러(err): 0.1584, 승리횟수(Win count): 22, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 88, 에러(err): 0.1939, 승리횟수(Win count): 22, 승리비율(Win ratio): 24.7191
# 반복(Epoch): 89, 에러(err): 0.1824, 승리횟수(Win count): 22, 승리비율(Win ratio): 24.4444
# 반복(Epoch): 90, 에러(err): 0.1661, 승리횟수(Win count): 22, 승리비율(Win ratio): 24.1758
# 반복(Epoch): 91, 에러(err): 0.2037, 승리횟수(Win count): 22, 승리비율(Win ratio): 23.9130
# 반복(Epoch): 92, 에러(err): 0.1953, 승리횟수(Win count): 22, 승리비율(Win ratio): 23.6559
# 반복(Epoch): 93, 에러(err): 0.2056, 승리횟수(Win count): 23, 승리비율(Win ratio): 24.4681
# 반복(Epoch): 94, 에러(err): 0.1961, 승리횟수(Win count): 23, 승리비율(Win ratio): 24.2105
# 반복(Epoch): 95, 에러(err): 0.2229, 승리횟수(Win count): 24, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 96, 에러(err): 0.2662, 승리횟수(Win count): 24, 승리비율(Win ratio): 24.7423
# 반복(Epoch): 97, 에러(err): 0.2821, 승리횟수(Win count): 24, 승리비율(Win ratio): 24.4898
# 반복(Epoch): 98, 에러(err): 0.2369, 승리횟수(Win count): 24, 승리비율(Win ratio): 24.2424
# 반복(Epoch): 99, 에러(err): 0.2194, 승리횟수(Win count): 24, 승리비율(Win ratio): 24.0000
# 반복(Epoch): 100, 에러(err): 0.2153, 승리횟수(Win count): 25, 승리비율(Win ratio): 24.7525
# 반복(Epoch): 101, 에러(err): 0.2264, 승리횟수(Win count): 25, 승리비율(Win ratio): 24.5098
# /content/model.ckpt-101 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 102, 에러(err): 0.2160, 승리횟수(Win count): 25, 승리비율(Win ratio): 24.2718
# 반복(Epoch): 103, 에러(err): 0.1758, 승리횟수(Win count): 26, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 104, 에러(err): 0.1500, 승리횟수(Win count): 27, 승리비율(Win ratio): 25.7143
# 반복(Epoch): 105, 에러(err): 0.2534, 승리횟수(Win count): 27, 승리비율(Win ratio): 25.4717
# 반복(Epoch): 106, 에러(err): 0.2676, 승리횟수(Win count): 27, 승리비율(Win ratio): 25.2336
# 반복(Epoch): 107, 에러(err): 0.1854, 승리횟수(Win count): 28, 승리비율(Win ratio): 25.9259
# 반복(Epoch): 108, 에러(err): 0.1815, 승리횟수(Win count): 28, 승리비율(Win ratio): 25.6881
# 반복(Epoch): 109, 에러(err): 0.2139, 승리횟수(Win count): 29, 승리비율(Win ratio): 26.3636
# 반복(Epoch): 110, 에러(err): 0.2066, 승리횟수(Win count): 29, 승리비율(Win ratio): 26.1261
# 반복(Epoch): 111, 에러(err): 0.2488, 승리횟수(Win count): 29, 승리비율(Win ratio): 25.8929
# 반복(Epoch): 112, 에러(err): 0.2324, 승리횟수(Win count): 30, 승리비율(Win ratio): 26.5487
# 반복(Epoch): 113, 에러(err): 0.2693, 승리횟수(Win count): 31, 승리비율(Win ratio): 27.1930
# 반복(Epoch): 114, 에러(err): 0.1994, 승리횟수(Win count): 32, 승리비율(Win ratio): 27.8261
# 반복(Epoch): 115, 에러(err): 0.1850, 승리횟수(Win count): 32, 승리비율(Win ratio): 27.5862
# 반복(Epoch): 116, 에러(err): 0.2235, 승리횟수(Win count): 32, 승리비율(Win ratio): 27.3504
# 반복(Epoch): 117, 에러(err): 0.1943, 승리횟수(Win count): 33, 승리비율(Win ratio): 27.9661
# 반복(Epoch): 118, 에러(err): 0.2629, 승리횟수(Win count): 33, 승리비율(Win ratio): 27.7311
# 반복(Epoch): 119, 에러(err): 0.2370, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.3333
# 반복(Epoch): 120, 에러(err): 0.1846, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.0992
# 반복(Epoch): 121, 에러(err): 0.2064, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.8689
# 반복(Epoch): 122, 에러(err): 0.2542, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.6423
# 반복(Epoch): 123, 에러(err): 0.2083, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.4194
# 반복(Epoch): 124, 에러(err): 0.1882, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.2000
# 반복(Epoch): 125, 에러(err): 0.2350, 승리횟수(Win count): 34, 승리비율(Win ratio): 26.9841
# 반복(Epoch): 126, 에러(err): 0.1681, 승리횟수(Win count): 35, 승리비율(Win ratio): 27.5591
# 반복(Epoch): 127, 에러(err): 0.2252, 승리횟수(Win count): 36, 승리비율(Win ratio): 28.1250
# 반복(Epoch): 128, 에러(err): 0.2135, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.9070
# 반복(Epoch): 129, 에러(err): 0.2148, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.6923
# 반복(Epoch): 130, 에러(err): 0.1476, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.4809
# 반복(Epoch): 131, 에러(err): 0.2557, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 132, 에러(err): 0.1983, 승리횟수(Win count): 37, 승리비율(Win ratio): 27.8195
# 반복(Epoch): 133, 에러(err): 0.2407, 승리횟수(Win count): 37, 승리비율(Win ratio): 27.6119
# 반복(Epoch): 134, 에러(err): 0.3035, 승리횟수(Win count): 37, 승리비율(Win ratio): 27.4074
# 반복(Epoch): 135, 에러(err): 0.2183, 승리횟수(Win count): 37, 승리비율(Win ratio): 27.2059
# 반복(Epoch): 136, 에러(err): 0.2366, 승리횟수(Win count): 38, 승리비율(Win ratio): 27.7372
# 반복(Epoch): 137, 에러(err): 0.2158, 승리횟수(Win count): 39, 승리비율(Win ratio): 28.2609
# 반복(Epoch): 138, 에러(err): 0.2038, 승리횟수(Win count): 39, 승리비율(Win ratio): 28.0576
# 반복(Epoch): 139, 에러(err): 0.2021, 승리횟수(Win count): 39, 승리비율(Win ratio): 27.8571
# 반복(Epoch): 140, 에러(err): 0.1720, 승리횟수(Win count): 39, 승리비율(Win ratio): 27.6596
# 반복(Epoch): 141, 에러(err): 0.1992, 승리횟수(Win count): 39, 승리비율(Win ratio): 27.4648
# 반복(Epoch): 142, 에러(err): 0.1962, 승리횟수(Win count): 40, 승리비율(Win ratio): 27.9720
# 반복(Epoch): 143, 에러(err): 0.2656, 승리횟수(Win count): 40, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 144, 에러(err): 0.1692, 승리횟수(Win count): 40, 승리비율(Win ratio): 27.5862
# 반복(Epoch): 145, 에러(err): 0.2789, 승리횟수(Win count): 40, 승리비율(Win ratio): 27.3973
# 반복(Epoch): 146, 에러(err): 0.2165, 승리횟수(Win count): 40, 승리비율(Win ratio): 27.2109
# 반복(Epoch): 147, 에러(err): 0.1919, 승리횟수(Win count): 41, 승리비율(Win ratio): 27.7027
# 반복(Epoch): 148, 에러(err): 0.1627, 승리횟수(Win count): 42, 승리비율(Win ratio): 28.1879
# 반복(Epoch): 149, 에러(err): 0.2348, 승리횟수(Win count): 42, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 150, 에러(err): 0.2342, 승리횟수(Win count): 43, 승리비율(Win ratio): 28.4768
# 반복(Epoch): 151, 에러(err): 0.1270, 승리횟수(Win count): 43, 승리비율(Win ratio): 28.2895
# 반복(Epoch): 152, 에러(err): 0.1917, 승리횟수(Win count): 44, 승리비율(Win ratio): 28.7582
# 반복(Epoch): 153, 에러(err): 0.2517, 승리횟수(Win count): 45, 승리비율(Win ratio): 29.2208
# 반복(Epoch): 154, 에러(err): 0.1709, 승리횟수(Win count): 46, 승리비율(Win ratio): 29.6774
# 반복(Epoch): 155, 에러(err): 0.1396, 승리횟수(Win count): 46, 승리비율(Win ratio): 29.4872
# 반복(Epoch): 156, 에러(err): 0.1998, 승리횟수(Win count): 47, 승리비율(Win ratio): 29.9363
# 반복(Epoch): 157, 에러(err): 0.1699, 승리횟수(Win count): 48, 승리비율(Win ratio): 30.3797
# 반복(Epoch): 158, 에러(err): 0.2310, 승리횟수(Win count): 49, 승리비율(Win ratio): 30.8176
# 반복(Epoch): 159, 에러(err): 0.1425, 승리횟수(Win count): 49, 승리비율(Win ratio): 30.6250
# 반복(Epoch): 160, 에러(err): 0.1628, 승리횟수(Win count): 49, 승리비율(Win ratio): 30.4348
# 반복(Epoch): 161, 에러(err): 0.3534, 승리횟수(Win count): 49, 승리비율(Win ratio): 30.2469
# 반복(Epoch): 162, 에러(err): 0.1779, 승리횟수(Win count): 50, 승리비율(Win ratio): 30.6748
# 반복(Epoch): 163, 에러(err): 0.2280, 승리횟수(Win count): 51, 승리비율(Win ratio): 31.0976
# 반복(Epoch): 164, 에러(err): 0.1809, 승리횟수(Win count): 52, 승리비율(Win ratio): 31.5152
# 반복(Epoch): 165, 에러(err): 0.1371, 승리횟수(Win count): 52, 승리비율(Win ratio): 31.3253
# 반복(Epoch): 166, 에러(err): 0.1769, 승리횟수(Win count): 52, 승리비율(Win ratio): 31.1377
# 반복(Epoch): 167, 에러(err): 0.1870, 승리횟수(Win count): 53, 승리비율(Win ratio): 31.5476
# 반복(Epoch): 168, 에러(err): 0.2072, 승리횟수(Win count): 53, 승리비율(Win ratio): 31.3609
# 반복(Epoch): 169, 에러(err): 0.2315, 승리횟수(Win count): 54, 승리비율(Win ratio): 31.7647
# 반복(Epoch): 170, 에러(err): 0.2877, 승리횟수(Win count): 54, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 171, 에러(err): 0.1647, 승리횟수(Win count): 54, 승리비율(Win ratio): 31.3953
# 반복(Epoch): 172, 에러(err): 0.1236, 승리횟수(Win count): 55, 승리비율(Win ratio): 31.7919
# 반복(Epoch): 173, 에러(err): 0.2504, 승리횟수(Win count): 55, 승리비율(Win ratio): 31.6092
# 반복(Epoch): 174, 에러(err): 0.1980, 승리횟수(Win count): 55, 승리비율(Win ratio): 31.4286
# 반복(Epoch): 175, 에러(err): 0.2103, 승리횟수(Win count): 55, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 176, 에러(err): 0.1940, 승리횟수(Win count): 56, 승리비율(Win ratio): 31.6384
# 반복(Epoch): 177, 에러(err): 0.1761, 승리횟수(Win count): 56, 승리비율(Win ratio): 31.4607
# 반복(Epoch): 178, 에러(err): 0.2114, 승리횟수(Win count): 57, 승리비율(Win ratio): 31.8436
# 반복(Epoch): 179, 에러(err): 0.1795, 승리횟수(Win count): 58, 승리비율(Win ratio): 32.2222
# 반복(Epoch): 180, 에러(err): 0.1573, 승리횟수(Win count): 59, 승리비율(Win ratio): 32.5967
# 반복(Epoch): 181, 에러(err): 0.1356, 승리횟수(Win count): 60, 승리비율(Win ratio): 32.9670
# 반복(Epoch): 182, 에러(err): 0.2821, 승리횟수(Win count): 61, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 183, 에러(err): 0.2015, 승리횟수(Win count): 62, 승리비율(Win ratio): 33.6957
# 반복(Epoch): 184, 에러(err): 0.2071, 승리횟수(Win count): 62, 승리비율(Win ratio): 33.5135
# 반복(Epoch): 185, 에러(err): 0.3259, 승리횟수(Win count): 62, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 186, 에러(err): 0.2518, 승리횟수(Win count): 63, 승리비율(Win ratio): 33.6898
# 반복(Epoch): 187, 에러(err): 0.2473, 승리횟수(Win count): 63, 승리비율(Win ratio): 33.5106
# 반복(Epoch): 188, 에러(err): 0.4073, 승리횟수(Win count): 64, 승리비율(Win ratio): 33.8624
# 반복(Epoch): 189, 에러(err): 0.1693, 승리횟수(Win count): 64, 승리비율(Win ratio): 33.6842
# 반복(Epoch): 190, 에러(err): 0.2046, 승리횟수(Win count): 65, 승리비율(Win ratio): 34.0314
# 반복(Epoch): 191, 에러(err): 0.1366, 승리횟수(Win count): 65, 승리비율(Win ratio): 33.8542
# 반복(Epoch): 192, 에러(err): 0.3555, 승리횟수(Win count): 66, 승리비율(Win ratio): 34.1969
# 반복(Epoch): 193, 에러(err): 0.1599, 승리횟수(Win count): 66, 승리비율(Win ratio): 34.0206
# 반복(Epoch): 194, 에러(err): 0.2352, 승리횟수(Win count): 66, 승리비율(Win ratio): 33.8462
# 반복(Epoch): 195, 에러(err): 0.1590, 승리횟수(Win count): 67, 승리비율(Win ratio): 34.1837
# 반복(Epoch): 196, 에러(err): 0.3280, 승리횟수(Win count): 67, 승리비율(Win ratio): 34.0102
# 반복(Epoch): 197, 에러(err): 0.1149, 승리횟수(Win count): 68, 승리비율(Win ratio): 34.3434
# 반복(Epoch): 198, 에러(err): 0.2951, 승리횟수(Win count): 68, 승리비율(Win ratio): 34.1709
# 반복(Epoch): 199, 에러(err): 0.3168, 승리횟수(Win count): 68, 승리비율(Win ratio): 34.0000
# 반복(Epoch): 200, 에러(err): 0.5999, 승리횟수(Win count): 69, 승리비율(Win ratio): 34.3284
# 반복(Epoch): 201, 에러(err): 0.1585, 승리횟수(Win count): 69, 승리비율(Win ratio): 34.1584
# /content/model.ckpt-201 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 202, 에러(err): 0.1667, 승리횟수(Win count): 70, 승리비율(Win ratio): 34.4828
# 반복(Epoch): 203, 에러(err): 0.1488, 승리횟수(Win count): 71, 승리비율(Win ratio): 34.8039
# 반복(Epoch): 204, 에러(err): 0.1996, 승리횟수(Win count): 72, 승리비율(Win ratio): 35.1220
# 반복(Epoch): 205, 에러(err): 0.1911, 승리횟수(Win count): 72, 승리비율(Win ratio): 34.9515
# 반복(Epoch): 206, 에러(err): 0.3444, 승리횟수(Win count): 73, 승리비율(Win ratio): 35.2657
# 반복(Epoch): 207, 에러(err): 0.2400, 승리횟수(Win count): 74, 승리비율(Win ratio): 35.5769
# 반복(Epoch): 208, 에러(err): 0.1193, 승리횟수(Win count): 75, 승리비율(Win ratio): 35.8852
# 반복(Epoch): 209, 에러(err): 0.3084, 승리횟수(Win count): 75, 승리비율(Win ratio): 35.7143
# 반복(Epoch): 210, 에러(err): 0.2127, 승리횟수(Win count): 76, 승리비율(Win ratio): 36.0190
# 반복(Epoch): 211, 에러(err): 0.4388, 승리횟수(Win count): 76, 승리비율(Win ratio): 35.8491
# 반복(Epoch): 212, 에러(err): 0.2614, 승리횟수(Win count): 77, 승리비율(Win ratio): 36.1502
# 반복(Epoch): 213, 에러(err): 0.2540, 승리횟수(Win count): 78, 승리비율(Win ratio): 36.4486
# 반복(Epoch): 214, 에러(err): 0.2103, 승리횟수(Win count): 78, 승리비율(Win ratio): 36.2791
# 반복(Epoch): 215, 에러(err): 0.2422, 승리횟수(Win count): 79, 승리비율(Win ratio): 36.5741
# 반복(Epoch): 216, 에러(err): 0.2670, 승리횟수(Win count): 79, 승리비율(Win ratio): 36.4055
# 반복(Epoch): 217, 에러(err): 0.1460, 승리횟수(Win count): 80, 승리비율(Win ratio): 36.6972
# 반복(Epoch): 218, 에러(err): 0.1515, 승리횟수(Win count): 81, 승리비율(Win ratio): 36.9863
# 반복(Epoch): 219, 에러(err): 0.1877, 승리횟수(Win count): 81, 승리비율(Win ratio): 36.8182
# 반복(Epoch): 220, 에러(err): 0.2672, 승리횟수(Win count): 81, 승리비율(Win ratio): 36.6516
# 반복(Epoch): 221, 에러(err): 0.1650, 승리횟수(Win count): 81, 승리비율(Win ratio): 36.4865
# 반복(Epoch): 222, 에러(err): 0.2673, 승리횟수(Win count): 82, 승리비율(Win ratio): 36.7713
# 반복(Epoch): 223, 에러(err): 0.3112, 승리횟수(Win count): 83, 승리비율(Win ratio): 37.0536
# 반복(Epoch): 224, 에러(err): 0.1509, 승리횟수(Win count): 84, 승리비율(Win ratio): 37.3333
# 반복(Epoch): 225, 에러(err): 0.3378, 승리횟수(Win count): 85, 승리비율(Win ratio): 37.6106
# 반복(Epoch): 226, 에러(err): 0.2010, 승리횟수(Win count): 86, 승리비율(Win ratio): 37.8855
# 반복(Epoch): 227, 에러(err): 0.3088, 승리횟수(Win count): 86, 승리비율(Win ratio): 37.7193
# 반복(Epoch): 228, 에러(err): 0.4272, 승리횟수(Win count): 87, 승리비율(Win ratio): 37.9913
# 반복(Epoch): 229, 에러(err): 0.1556, 승리횟수(Win count): 88, 승리비율(Win ratio): 38.2609
# 반복(Epoch): 230, 에러(err): 0.4450, 승리횟수(Win count): 89, 승리비율(Win ratio): 38.5281
# 반복(Epoch): 231, 에러(err): 0.2137, 승리횟수(Win count): 90, 승리비율(Win ratio): 38.7931
# 반복(Epoch): 232, 에러(err): 0.2700, 승리횟수(Win count): 91, 승리비율(Win ratio): 39.0558
# 반복(Epoch): 233, 에러(err): 0.4481, 승리횟수(Win count): 91, 승리비율(Win ratio): 38.8889
# 반복(Epoch): 234, 에러(err): 0.1553, 승리횟수(Win count): 92, 승리비율(Win ratio): 39.1489
# 반복(Epoch): 235, 에러(err): 0.2376, 승리횟수(Win count): 93, 승리비율(Win ratio): 39.4068
# 반복(Epoch): 236, 에러(err): 0.1813, 승리횟수(Win count): 93, 승리비율(Win ratio): 39.2405
# 반복(Epoch): 237, 에러(err): 0.1605, 승리횟수(Win count): 94, 승리비율(Win ratio): 39.4958
# 반복(Epoch): 238, 에러(err): 0.2119, 승리횟수(Win count): 94, 승리비율(Win ratio): 39.3305
# 반복(Epoch): 239, 에러(err): 0.1587, 승리횟수(Win count): 95, 승리비율(Win ratio): 39.5833
# 반복(Epoch): 240, 에러(err): 0.1401, 승리횟수(Win count): 96, 승리비율(Win ratio): 39.8340
# 반복(Epoch): 241, 에러(err): 0.2732, 승리횟수(Win count): 97, 승리비율(Win ratio): 40.0826
# 반복(Epoch): 242, 에러(err): 0.1638, 승리횟수(Win count): 98, 승리비율(Win ratio): 40.3292
# 반복(Epoch): 243, 에러(err): 0.1836, 승리횟수(Win count): 99, 승리비율(Win ratio): 40.5738
# 반복(Epoch): 244, 에러(err): 0.1045, 승리횟수(Win count): 100, 승리비율(Win ratio): 40.8163
# 반복(Epoch): 245, 에러(err): 0.2935, 승리횟수(Win count): 101, 승리비율(Win ratio): 41.0569
# 반복(Epoch): 246, 에러(err): 0.1008, 승리횟수(Win count): 102, 승리비율(Win ratio): 41.2955
# 반복(Epoch): 247, 에러(err): 0.1385, 승리횟수(Win count): 103, 승리비율(Win ratio): 41.5323
# 반복(Epoch): 248, 에러(err): 0.1943, 승리횟수(Win count): 103, 승리비율(Win ratio): 41.3655
# 반복(Epoch): 249, 에러(err): 0.1742, 승리횟수(Win count): 104, 승리비율(Win ratio): 41.6000
# 반복(Epoch): 250, 에러(err): 0.1505, 승리횟수(Win count): 104, 승리비율(Win ratio): 41.4343
# 반복(Epoch): 251, 에러(err): 0.3480, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.6667
# 반복(Epoch): 252, 에러(err): 0.1521, 승리횟수(Win count): 106, 승리비율(Win ratio): 41.8972
# 반복(Epoch): 253, 에러(err): 0.2537, 승리횟수(Win count): 107, 승리비율(Win ratio): 42.1260
# 반복(Epoch): 254, 에러(err): 0.1233, 승리횟수(Win count): 108, 승리비율(Win ratio): 42.3529
# 반복(Epoch): 255, 에러(err): 0.1296, 승리횟수(Win count): 108, 승리비율(Win ratio): 42.1875
# 반복(Epoch): 256, 에러(err): 0.1354, 승리횟수(Win count): 108, 승리비율(Win ratio): 42.0233
# 반복(Epoch): 257, 에러(err): 0.1149, 승리횟수(Win count): 109, 승리비율(Win ratio): 42.2481
# 반복(Epoch): 258, 에러(err): 0.1889, 승리횟수(Win count): 110, 승리비율(Win ratio): 42.4710
# 반복(Epoch): 259, 에러(err): 0.0950, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.6923
# 반복(Epoch): 260, 에러(err): 0.2109, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.5287
# 반복(Epoch): 261, 에러(err): 0.1480, 승리횟수(Win count): 112, 승리비율(Win ratio): 42.7481
# 반복(Epoch): 262, 에러(err): 0.1654, 승리횟수(Win count): 113, 승리비율(Win ratio): 42.9658
# 반복(Epoch): 263, 에러(err): 0.1519, 승리횟수(Win count): 113, 승리비율(Win ratio): 42.8030
# 반복(Epoch): 264, 에러(err): 0.1541, 승리횟수(Win count): 114, 승리비율(Win ratio): 43.0189
# 반복(Epoch): 265, 에러(err): 0.0898, 승리횟수(Win count): 115, 승리비율(Win ratio): 43.2331
# 반복(Epoch): 266, 에러(err): 0.0705, 승리횟수(Win count): 116, 승리비율(Win ratio): 43.4457
# 반복(Epoch): 267, 에러(err): 0.1350, 승리횟수(Win count): 116, 승리비율(Win ratio): 43.2836
# 반복(Epoch): 268, 에러(err): 0.0639, 승리횟수(Win count): 116, 승리비율(Win ratio): 43.1227
# 반복(Epoch): 269, 에러(err): 0.0735, 승리횟수(Win count): 117, 승리비율(Win ratio): 43.3333
# 반복(Epoch): 270, 에러(err): 0.1403, 승리횟수(Win count): 118, 승리비율(Win ratio): 43.5424
# 반복(Epoch): 271, 에러(err): 0.1352, 승리횟수(Win count): 118, 승리비율(Win ratio): 43.3824
# 반복(Epoch): 272, 에러(err): 0.0911, 승리횟수(Win count): 118, 승리비율(Win ratio): 43.2234
# 반복(Epoch): 273, 에러(err): 0.1256, 승리횟수(Win count): 119, 승리비율(Win ratio): 43.4307
# 반복(Epoch): 274, 에러(err): 0.1083, 승리횟수(Win count): 120, 승리비율(Win ratio): 43.6364
# 반복(Epoch): 275, 에러(err): 0.1215, 승리횟수(Win count): 121, 승리비율(Win ratio): 43.8406
# 반복(Epoch): 276, 에러(err): 0.1028, 승리횟수(Win count): 121, 승리비율(Win ratio): 43.6823
# 반복(Epoch): 277, 에러(err): 0.0841, 승리횟수(Win count): 122, 승리비율(Win ratio): 43.8849
# 반복(Epoch): 278, 에러(err): 0.0581, 승리횟수(Win count): 123, 승리비율(Win ratio): 44.0860
# 반복(Epoch): 279, 에러(err): 0.0887, 승리횟수(Win count): 124, 승리비율(Win ratio): 44.2857
# 반복(Epoch): 280, 에러(err): 0.0718, 승리횟수(Win count): 125, 승리비율(Win ratio): 44.4840
# 반복(Epoch): 281, 에러(err): 0.0962, 승리횟수(Win count): 125, 승리비율(Win ratio): 44.3262
# 반복(Epoch): 282, 에러(err): 0.0763, 승리횟수(Win count): 126, 승리비율(Win ratio): 44.5230
# 반복(Epoch): 283, 에러(err): 0.0662, 승리횟수(Win count): 127, 승리비율(Win ratio): 44.7183
# 반복(Epoch): 284, 에러(err): 0.0730, 승리횟수(Win count): 127, 승리비율(Win ratio): 44.5614
# 반복(Epoch): 285, 에러(err): 0.0866, 승리횟수(Win count): 128, 승리비율(Win ratio): 44.7552
# 반복(Epoch): 286, 에러(err): 0.0816, 승리횟수(Win count): 129, 승리비율(Win ratio): 44.9477
# 반복(Epoch): 287, 에러(err): 0.0935, 승리횟수(Win count): 130, 승리비율(Win ratio): 45.1389
# 반복(Epoch): 288, 에러(err): 0.0741, 승리횟수(Win count): 131, 승리비율(Win ratio): 45.3287
# 반복(Epoch): 289, 에러(err): 0.0921, 승리횟수(Win count): 132, 승리비율(Win ratio): 45.5172
# 반복(Epoch): 290, 에러(err): 0.0544, 승리횟수(Win count): 132, 승리비율(Win ratio): 45.3608
# 반복(Epoch): 291, 에러(err): 0.0853, 승리횟수(Win count): 133, 승리비율(Win ratio): 45.5479
# 반복(Epoch): 292, 에러(err): 0.0851, 승리횟수(Win count): 134, 승리비율(Win ratio): 45.7338
# 반복(Epoch): 293, 에러(err): 0.0820, 승리횟수(Win count): 135, 승리비율(Win ratio): 45.9184
# 반복(Epoch): 294, 에러(err): 0.0295, 승리횟수(Win count): 136, 승리비율(Win ratio): 46.1017
# 반복(Epoch): 295, 에러(err): 0.0488, 승리횟수(Win count): 137, 승리비율(Win ratio): 46.2838
# 반복(Epoch): 296, 에러(err): 0.0326, 승리횟수(Win count): 138, 승리비율(Win ratio): 46.4646
# 반복(Epoch): 297, 에러(err): 0.0802, 승리횟수(Win count): 139, 승리비율(Win ratio): 46.6443
# 반복(Epoch): 298, 에러(err): 0.0966, 승리횟수(Win count): 140, 승리비율(Win ratio): 46.8227
# 반복(Epoch): 299, 에러(err): 0.0342, 승리횟수(Win count): 140, 승리비율(Win ratio): 46.6667
# 반복(Epoch): 300, 에러(err): 0.0482, 승리횟수(Win count): 140, 승리비율(Win ratio): 46.5116
# 반복(Epoch): 301, 에러(err): 0.0349, 승리횟수(Win count): 141, 승리비율(Win ratio): 46.6887
# /content/model.ckpt-301 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 302, 에러(err): 0.0523, 승리횟수(Win count): 142, 승리비율(Win ratio): 46.8647
# 반복(Epoch): 303, 에러(err): 0.0291, 승리횟수(Win count): 143, 승리비율(Win ratio): 47.0395
# 반복(Epoch): 304, 에러(err): 0.0491, 승리횟수(Win count): 144, 승리비율(Win ratio): 47.2131
# 반복(Epoch): 305, 에러(err): 0.0665, 승리횟수(Win count): 145, 승리비율(Win ratio): 47.3856
# 반복(Epoch): 306, 에러(err): 0.0984, 승리횟수(Win count): 145, 승리비율(Win ratio): 47.2313
# 반복(Epoch): 307, 에러(err): 0.0298, 승리횟수(Win count): 146, 승리비율(Win ratio): 47.4026
# 반복(Epoch): 308, 에러(err): 0.0268, 승리횟수(Win count): 147, 승리비율(Win ratio): 47.5728
# 반복(Epoch): 309, 에러(err): 0.0236, 승리횟수(Win count): 148, 승리비율(Win ratio): 47.7419
# 반복(Epoch): 310, 에러(err): 0.0447, 승리횟수(Win count): 149, 승리비율(Win ratio): 47.9100
# 반복(Epoch): 311, 에러(err): 0.0264, 승리횟수(Win count): 150, 승리비율(Win ratio): 48.0769
# 반복(Epoch): 312, 에러(err): 0.0354, 승리횟수(Win count): 150, 승리비율(Win ratio): 47.9233
# 반복(Epoch): 313, 에러(err): 0.0345, 승리횟수(Win count): 150, 승리비율(Win ratio): 47.7707
# 반복(Epoch): 314, 에러(err): 0.0269, 승리횟수(Win count): 151, 승리비율(Win ratio): 47.9365
# 반복(Epoch): 315, 에러(err): 0.0502, 승리횟수(Win count): 152, 승리비율(Win ratio): 48.1013
# 반복(Epoch): 316, 에러(err): 0.0630, 승리횟수(Win count): 153, 승리비율(Win ratio): 48.2650
# 반복(Epoch): 317, 에러(err): 0.0515, 승리횟수(Win count): 153, 승리비율(Win ratio): 48.1132
# 반복(Epoch): 318, 에러(err): 0.0257, 승리횟수(Win count): 153, 승리비율(Win ratio): 47.9624
# 반복(Epoch): 319, 에러(err): 0.0547, 승리횟수(Win count): 154, 승리비율(Win ratio): 48.1250
# 반복(Epoch): 320, 에러(err): 0.0453, 승리횟수(Win count): 155, 승리비율(Win ratio): 48.2866
# 반복(Epoch): 321, 에러(err): 0.0432, 승리횟수(Win count): 155, 승리비율(Win ratio): 48.1366
# 반복(Epoch): 322, 에러(err): 0.0169, 승리횟수(Win count): 156, 승리비율(Win ratio): 48.2972
# 반복(Epoch): 323, 에러(err): 0.0158, 승리횟수(Win count): 157, 승리비율(Win ratio): 48.4568
# 반복(Epoch): 324, 에러(err): 0.0322, 승리횟수(Win count): 157, 승리비율(Win ratio): 48.3077
# 반복(Epoch): 325, 에러(err): 0.0361, 승리횟수(Win count): 158, 승리비율(Win ratio): 48.4663
# 반복(Epoch): 326, 에러(err): 0.0326, 승리횟수(Win count): 159, 승리비율(Win ratio): 48.6239
# 반복(Epoch): 327, 에러(err): 0.0296, 승리횟수(Win count): 160, 승리비율(Win ratio): 48.7805
# 반복(Epoch): 328, 에러(err): 0.0217, 승리횟수(Win count): 161, 승리비율(Win ratio): 48.9362
# 반복(Epoch): 329, 에러(err): 0.0469, 승리횟수(Win count): 162, 승리비율(Win ratio): 49.0909
# 반복(Epoch): 330, 에러(err): 0.0209, 승리횟수(Win count): 162, 승리비율(Win ratio): 48.9426
# 반복(Epoch): 331, 에러(err): 0.0669, 승리횟수(Win count): 163, 승리비율(Win ratio): 49.0964
# 반복(Epoch): 332, 에러(err): 0.0150, 승리횟수(Win count): 163, 승리비율(Win ratio): 48.9489
# 반복(Epoch): 333, 에러(err): 0.0552, 승리횟수(Win count): 163, 승리비율(Win ratio): 48.8024
# 반복(Epoch): 334, 에러(err): 0.0263, 승리횟수(Win count): 164, 승리비율(Win ratio): 48.9552
# 반복(Epoch): 335, 에러(err): 0.0172, 승리횟수(Win count): 165, 승리비율(Win ratio): 49.1071
# 반복(Epoch): 336, 에러(err): 0.1093, 승리횟수(Win count): 166, 승리비율(Win ratio): 49.2582
# 반복(Epoch): 337, 에러(err): 0.0991, 승리횟수(Win count): 167, 승리비율(Win ratio): 49.4083
# 반복(Epoch): 338, 에러(err): 0.0883, 승리횟수(Win count): 168, 승리비율(Win ratio): 49.5575
# 반복(Epoch): 339, 에러(err): 0.1316, 승리횟수(Win count): 168, 승리비율(Win ratio): 49.4118
# 반복(Epoch): 340, 에러(err): 0.0182, 승리횟수(Win count): 169, 승리비율(Win ratio): 49.5601
# 반복(Epoch): 341, 에러(err): 0.1126, 승리횟수(Win count): 170, 승리비율(Win ratio): 49.7076
# 반복(Epoch): 342, 에러(err): 0.2893, 승리횟수(Win count): 171, 승리비율(Win ratio): 49.8542
# 반복(Epoch): 343, 에러(err): 0.1759, 승리횟수(Win count): 172, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 344, 에러(err): 0.0696, 승리횟수(Win count): 173, 승리비율(Win ratio): 50.1449
# 반복(Epoch): 345, 에러(err): 0.0435, 승리횟수(Win count): 174, 승리비율(Win ratio): 50.2890
# 반복(Epoch): 346, 에러(err): 0.0458, 승리횟수(Win count): 175, 승리비율(Win ratio): 50.4323
# 반복(Epoch): 347, 에러(err): 0.0256, 승리횟수(Win count): 175, 승리비율(Win ratio): 50.2874
# 반복(Epoch): 348, 에러(err): 0.0455, 승리횟수(Win count): 176, 승리비율(Win ratio): 50.4298
# 반복(Epoch): 349, 에러(err): 0.1369, 승리횟수(Win count): 176, 승리비율(Win ratio): 50.2857
# 반복(Epoch): 350, 에러(err): 0.2481, 승리횟수(Win count): 177, 승리비율(Win ratio): 50.4274
# 반복(Epoch): 351, 에러(err): 0.0362, 승리횟수(Win count): 178, 승리비율(Win ratio): 50.5682
# 반복(Epoch): 352, 에러(err): 0.0605, 승리횟수(Win count): 179, 승리비율(Win ratio): 50.7082
# 반복(Epoch): 353, 에러(err): 0.0649, 승리횟수(Win count): 179, 승리비율(Win ratio): 50.5650
# 반복(Epoch): 354, 에러(err): 0.0440, 승리횟수(Win count): 180, 승리비율(Win ratio): 50.7042
# 반복(Epoch): 355, 에러(err): 0.1599, 승리횟수(Win count): 181, 승리비율(Win ratio): 50.8427
# 반복(Epoch): 356, 에러(err): 0.1245, 승리횟수(Win count): 182, 승리비율(Win ratio): 50.9804
# 반복(Epoch): 357, 에러(err): 0.0866, 승리횟수(Win count): 182, 승리비율(Win ratio): 50.8380
# 반복(Epoch): 358, 에러(err): 0.0668, 승리횟수(Win count): 183, 승리비율(Win ratio): 50.9749
# 반복(Epoch): 359, 에러(err): 0.2342, 승리횟수(Win count): 184, 승리비율(Win ratio): 51.1111
# 반복(Epoch): 360, 에러(err): 0.0961, 승리횟수(Win count): 184, 승리비율(Win ratio): 50.9695
# 반복(Epoch): 361, 에러(err): 0.0558, 승리횟수(Win count): 185, 승리비율(Win ratio): 51.1050
# 반복(Epoch): 362, 에러(err): 0.0488, 승리횟수(Win count): 186, 승리비율(Win ratio): 51.2397
# 반복(Epoch): 363, 에러(err): 0.0295, 승리횟수(Win count): 187, 승리비율(Win ratio): 51.3736
# 반복(Epoch): 364, 에러(err): 0.1105, 승리횟수(Win count): 188, 승리비율(Win ratio): 51.5068
# 반복(Epoch): 365, 에러(err): 0.0223, 승리횟수(Win count): 188, 승리비율(Win ratio): 51.3661
# 반복(Epoch): 366, 에러(err): 0.0411, 승리횟수(Win count): 189, 승리비율(Win ratio): 51.4986
# 반복(Epoch): 367, 에러(err): 0.0414, 승리횟수(Win count): 190, 승리비율(Win ratio): 51.6304
# 반복(Epoch): 368, 에러(err): 0.0284, 승리횟수(Win count): 191, 승리비율(Win ratio): 51.7615
# 반복(Epoch): 369, 에러(err): 0.0421, 승리횟수(Win count): 192, 승리비율(Win ratio): 51.8919
# 반복(Epoch): 370, 에러(err): 0.1109, 승리횟수(Win count): 192, 승리비율(Win ratio): 51.7520
# 반복(Epoch): 371, 에러(err): 0.0604, 승리횟수(Win count): 193, 승리비율(Win ratio): 51.8817
# 반복(Epoch): 372, 에러(err): 0.0543, 승리횟수(Win count): 194, 승리비율(Win ratio): 52.0107
# 반복(Epoch): 373, 에러(err): 0.0467, 승리횟수(Win count): 194, 승리비율(Win ratio): 51.8717
# 반복(Epoch): 374, 에러(err): 0.0433, 승리횟수(Win count): 195, 승리비율(Win ratio): 52.0000
# 반복(Epoch): 375, 에러(err): 0.0179, 승리횟수(Win count): 196, 승리비율(Win ratio): 52.1277
# 반복(Epoch): 376, 에러(err): 0.0215, 승리횟수(Win count): 197, 승리비율(Win ratio): 52.2546
# 반복(Epoch): 377, 에러(err): 0.0435, 승리횟수(Win count): 198, 승리비율(Win ratio): 52.3810
# 반복(Epoch): 378, 에러(err): 0.0279, 승리횟수(Win count): 199, 승리비율(Win ratio): 52.5066
# 반복(Epoch): 379, 에러(err): 0.0372, 승리횟수(Win count): 199, 승리비율(Win ratio): 52.3684
# 반복(Epoch): 380, 에러(err): 0.1135, 승리횟수(Win count): 199, 승리비율(Win ratio): 52.2310
# 반복(Epoch): 381, 에러(err): 0.1105, 승리횟수(Win count): 199, 승리비율(Win ratio): 52.0942
# 반복(Epoch): 382, 에러(err): 0.0856, 승리횟수(Win count): 200, 승리비율(Win ratio): 52.2193
# 반복(Epoch): 383, 에러(err): 0.0681, 승리횟수(Win count): 201, 승리비율(Win ratio): 52.3438
# 반복(Epoch): 384, 에러(err): 0.0655, 승리횟수(Win count): 202, 승리비율(Win ratio): 52.4675
# 반복(Epoch): 385, 에러(err): 0.1111, 승리횟수(Win count): 203, 승리비율(Win ratio): 52.5907
# 반복(Epoch): 386, 에러(err): 0.0571, 승리횟수(Win count): 203, 승리비율(Win ratio): 52.4548
# 반복(Epoch): 387, 에러(err): 0.1389, 승리횟수(Win count): 204, 승리비율(Win ratio): 52.5773
# 반복(Epoch): 388, 에러(err): 0.0578, 승리횟수(Win count): 205, 승리비율(Win ratio): 52.6992
# 반복(Epoch): 389, 에러(err): 0.0536, 승리횟수(Win count): 206, 승리비율(Win ratio): 52.8205
# 반복(Epoch): 390, 에러(err): 0.0593, 승리횟수(Win count): 206, 승리비율(Win ratio): 52.6854
# 반복(Epoch): 391, 에러(err): 0.0924, 승리횟수(Win count): 207, 승리비율(Win ratio): 52.8061
# 반복(Epoch): 392, 에러(err): 0.0765, 승리횟수(Win count): 208, 승리비율(Win ratio): 52.9262
# 반복(Epoch): 393, 에러(err): 0.1034, 승리횟수(Win count): 209, 승리비율(Win ratio): 53.0457
# 반복(Epoch): 394, 에러(err): 0.0958, 승리횟수(Win count): 210, 승리비율(Win ratio): 53.1646
# 반복(Epoch): 395, 에러(err): 0.0299, 승리횟수(Win count): 211, 승리비율(Win ratio): 53.2828
# 반복(Epoch): 396, 에러(err): 0.1019, 승리횟수(Win count): 212, 승리비율(Win ratio): 53.4005
# 반복(Epoch): 397, 에러(err): 0.0268, 승리횟수(Win count): 212, 승리비율(Win ratio): 53.2663
# 반복(Epoch): 398, 에러(err): 0.0209, 승리횟수(Win count): 212, 승리비율(Win ratio): 53.1328
# 반복(Epoch): 399, 에러(err): 0.0242, 승리횟수(Win count): 213, 승리비율(Win ratio): 53.2500
# 반복(Epoch): 400, 에러(err): 0.0178, 승리횟수(Win count): 214, 승리비율(Win ratio): 53.3666
# 반복(Epoch): 401, 에러(err): 0.1587, 승리횟수(Win count): 215, 승리비율(Win ratio): 53.4826
# /content/model.ckpt-401 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 402, 에러(err): 0.0515, 승리횟수(Win count): 215, 승리비율(Win ratio): 53.3499
# 반복(Epoch): 403, 에러(err): 0.0298, 승리횟수(Win count): 216, 승리비율(Win ratio): 53.4653
# 반복(Epoch): 404, 에러(err): 0.0200, 승리횟수(Win count): 217, 승리비율(Win ratio): 53.5802
# 반복(Epoch): 405, 에러(err): 0.0158, 승리횟수(Win count): 218, 승리비율(Win ratio): 53.6946
# 반복(Epoch): 406, 에러(err): 0.0256, 승리횟수(Win count): 219, 승리비율(Win ratio): 53.8084
# 반복(Epoch): 407, 에러(err): 0.0752, 승리횟수(Win count): 220, 승리비율(Win ratio): 53.9216
# 반복(Epoch): 408, 에러(err): 0.0511, 승리횟수(Win count): 221, 승리비율(Win ratio): 54.0342
# 반복(Epoch): 409, 에러(err): 0.0699, 승리횟수(Win count): 221, 승리비율(Win ratio): 53.9024
# 반복(Epoch): 410, 에러(err): 0.0605, 승리횟수(Win count): 222, 승리비율(Win ratio): 54.0146
# 반복(Epoch): 411, 에러(err): 0.0457, 승리횟수(Win count): 223, 승리비율(Win ratio): 54.1262
# 반복(Epoch): 412, 에러(err): 0.0116, 승리횟수(Win count): 223, 승리비율(Win ratio): 53.9952
# 반복(Epoch): 413, 에러(err): 0.0597, 승리횟수(Win count): 224, 승리비율(Win ratio): 54.1063
# 반복(Epoch): 414, 에러(err): 0.0383, 승리횟수(Win count): 225, 승리비율(Win ratio): 54.2169
# 반복(Epoch): 415, 에러(err): 0.0260, 승리횟수(Win count): 225, 승리비율(Win ratio): 54.0865
# 반복(Epoch): 416, 에러(err): 0.0235, 승리횟수(Win count): 226, 승리비율(Win ratio): 54.1966
# 반복(Epoch): 417, 에러(err): 0.0404, 승리횟수(Win count): 227, 승리비율(Win ratio): 54.3062
# 반복(Epoch): 418, 에러(err): 0.0210, 승리횟수(Win count): 228, 승리비율(Win ratio): 54.4153
# 반복(Epoch): 419, 에러(err): 0.0208, 승리횟수(Win count): 229, 승리비율(Win ratio): 54.5238
# 반복(Epoch): 420, 에러(err): 0.0122, 승리횟수(Win count): 230, 승리비율(Win ratio): 54.6318
# 반복(Epoch): 421, 에러(err): 0.0202, 승리횟수(Win count): 230, 승리비율(Win ratio): 54.5024
# 반복(Epoch): 422, 에러(err): 0.0128, 승리횟수(Win count): 231, 승리비율(Win ratio): 54.6099
# 반복(Epoch): 423, 에러(err): 0.0527, 승리횟수(Win count): 231, 승리비율(Win ratio): 54.4811
# 반복(Epoch): 424, 에러(err): 0.0144, 승리횟수(Win count): 232, 승리비율(Win ratio): 54.5882
# 반복(Epoch): 425, 에러(err): 0.0129, 승리횟수(Win count): 233, 승리비율(Win ratio): 54.6948
# 반복(Epoch): 426, 에러(err): 0.0129, 승리횟수(Win count): 234, 승리비율(Win ratio): 54.8009
# 반복(Epoch): 427, 에러(err): 0.0187, 승리횟수(Win count): 234, 승리비율(Win ratio): 54.6729
# 반복(Epoch): 428, 에러(err): 0.0131, 승리횟수(Win count): 235, 승리비율(Win ratio): 54.7786
# 반복(Epoch): 429, 에러(err): 0.0205, 승리횟수(Win count): 236, 승리비율(Win ratio): 54.8837
# 반복(Epoch): 430, 에러(err): 0.0300, 승리횟수(Win count): 237, 승리비율(Win ratio): 54.9884
# 반복(Epoch): 431, 에러(err): 0.0271, 승리횟수(Win count): 238, 승리비율(Win ratio): 55.0926
# 반복(Epoch): 432, 에러(err): 0.0256, 승리횟수(Win count): 239, 승리비율(Win ratio): 55.1963
# 반복(Epoch): 433, 에러(err): 0.0184, 승리횟수(Win count): 240, 승리비율(Win ratio): 55.2995
# 반복(Epoch): 434, 에러(err): 0.0183, 승리횟수(Win count): 241, 승리비율(Win ratio): 55.4023
# 반복(Epoch): 435, 에러(err): 0.0261, 승리횟수(Win count): 242, 승리비율(Win ratio): 55.5046
# 반복(Epoch): 436, 에러(err): 0.0342, 승리횟수(Win count): 243, 승리비율(Win ratio): 55.6064
# 반복(Epoch): 437, 에러(err): 0.0185, 승리횟수(Win count): 244, 승리비율(Win ratio): 55.7078
# 반복(Epoch): 438, 에러(err): 0.0135, 승리횟수(Win count): 245, 승리비율(Win ratio): 55.8087
# 반복(Epoch): 439, 에러(err): 0.0135, 승리횟수(Win count): 246, 승리비율(Win ratio): 55.9091
# 반복(Epoch): 440, 에러(err): 0.0179, 승리횟수(Win count): 247, 승리비율(Win ratio): 56.0091
# 반복(Epoch): 441, 에러(err): 0.0103, 승리횟수(Win count): 247, 승리비율(Win ratio): 55.8824
# 반복(Epoch): 442, 에러(err): 0.0190, 승리횟수(Win count): 248, 승리비율(Win ratio): 55.9819
# 반복(Epoch): 443, 에러(err): 0.0159, 승리횟수(Win count): 248, 승리비율(Win ratio): 55.8559
# 반복(Epoch): 444, 에러(err): 0.0287, 승리횟수(Win count): 248, 승리비율(Win ratio): 55.7303
# 반복(Epoch): 445, 에러(err): 0.0348, 승리횟수(Win count): 248, 승리비율(Win ratio): 55.6054
# 반복(Epoch): 446, 에러(err): 0.0400, 승리횟수(Win count): 248, 승리비율(Win ratio): 55.4810
# 반복(Epoch): 447, 에러(err): 0.0114, 승리횟수(Win count): 248, 승리비율(Win ratio): 55.3571
# 반복(Epoch): 448, 에러(err): 0.0109, 승리횟수(Win count): 249, 승리비율(Win ratio): 55.4566
# 반복(Epoch): 449, 에러(err): 0.0117, 승리횟수(Win count): 250, 승리비율(Win ratio): 55.5556
# 반복(Epoch): 450, 에러(err): 0.0096, 승리횟수(Win count): 250, 승리비율(Win ratio): 55.4324
# 반복(Epoch): 451, 에러(err): 0.0269, 승리횟수(Win count): 251, 승리비율(Win ratio): 55.5310
# 반복(Epoch): 452, 에러(err): 0.0127, 승리횟수(Win count): 252, 승리비율(Win ratio): 55.6291
# 반복(Epoch): 453, 에러(err): 0.0159, 승리횟수(Win count): 253, 승리비율(Win ratio): 55.7269
# 반복(Epoch): 454, 에러(err): 0.0246, 승리횟수(Win count): 254, 승리비율(Win ratio): 55.8242
# 반복(Epoch): 455, 에러(err): 0.0088, 승리횟수(Win count): 255, 승리비율(Win ratio): 55.9211
# 반복(Epoch): 456, 에러(err): 0.0176, 승리횟수(Win count): 256, 승리비율(Win ratio): 56.0175
# 반복(Epoch): 457, 에러(err): 0.0153, 승리횟수(Win count): 257, 승리비율(Win ratio): 56.1135
# 반복(Epoch): 458, 에러(err): 0.0101, 승리횟수(Win count): 258, 승리비율(Win ratio): 56.2092
# 반복(Epoch): 459, 에러(err): 0.0229, 승리횟수(Win count): 259, 승리비율(Win ratio): 56.3043
# 반복(Epoch): 460, 에러(err): 0.0138, 승리횟수(Win count): 260, 승리비율(Win ratio): 56.3991
# 반복(Epoch): 461, 에러(err): 0.0308, 승리횟수(Win count): 261, 승리비율(Win ratio): 56.4935
# 반복(Epoch): 462, 에러(err): 0.0144, 승리횟수(Win count): 262, 승리비율(Win ratio): 56.5875
# 반복(Epoch): 463, 에러(err): 0.0228, 승리횟수(Win count): 263, 승리비율(Win ratio): 56.6810
# 반복(Epoch): 464, 에러(err): 0.0534, 승리횟수(Win count): 264, 승리비율(Win ratio): 56.7742
# 반복(Epoch): 465, 에러(err): 0.0267, 승리횟수(Win count): 265, 승리비율(Win ratio): 56.8670
# 반복(Epoch): 466, 에러(err): 0.0119, 승리횟수(Win count): 266, 승리비율(Win ratio): 56.9593
# 반복(Epoch): 467, 에러(err): 0.0277, 승리횟수(Win count): 267, 승리비율(Win ratio): 57.0513
# 반복(Epoch): 468, 에러(err): 0.0135, 승리횟수(Win count): 268, 승리비율(Win ratio): 57.1429
# 반복(Epoch): 469, 에러(err): 0.0208, 승리횟수(Win count): 269, 승리비율(Win ratio): 57.2340
# 반복(Epoch): 470, 에러(err): 0.0102, 승리횟수(Win count): 270, 승리비율(Win ratio): 57.3248
# 반복(Epoch): 471, 에러(err): 0.0359, 승리횟수(Win count): 271, 승리비율(Win ratio): 57.4153
# 반복(Epoch): 472, 에러(err): 0.0059, 승리횟수(Win count): 272, 승리비율(Win ratio): 57.5053
# 반복(Epoch): 473, 에러(err): 0.0141, 승리횟수(Win count): 273, 승리비율(Win ratio): 57.5949
# 반복(Epoch): 474, 에러(err): 0.0123, 승리횟수(Win count): 274, 승리비율(Win ratio): 57.6842
# 반복(Epoch): 475, 에러(err): 0.0124, 승리횟수(Win count): 275, 승리비율(Win ratio): 57.7731
# 반복(Epoch): 476, 에러(err): 0.0187, 승리횟수(Win count): 276, 승리비율(Win ratio): 57.8616
# 반복(Epoch): 477, 에러(err): 0.0112, 승리횟수(Win count): 277, 승리비율(Win ratio): 57.9498
# 반복(Epoch): 478, 에러(err): 0.0189, 승리횟수(Win count): 278, 승리비율(Win ratio): 58.0376
# 반복(Epoch): 479, 에러(err): 0.0089, 승리횟수(Win count): 279, 승리비율(Win ratio): 58.1250
# 반복(Epoch): 480, 에러(err): 0.0161, 승리횟수(Win count): 280, 승리비율(Win ratio): 58.2121
# 반복(Epoch): 481, 에러(err): 0.0183, 승리횟수(Win count): 281, 승리비율(Win ratio): 58.2988
# 반복(Epoch): 482, 에러(err): 0.0097, 승리횟수(Win count): 282, 승리비율(Win ratio): 58.3851
# 반복(Epoch): 483, 에러(err): 0.0115, 승리횟수(Win count): 283, 승리비율(Win ratio): 58.4711
# 반복(Epoch): 484, 에러(err): 0.0174, 승리횟수(Win count): 283, 승리비율(Win ratio): 58.3505
# 반복(Epoch): 485, 에러(err): 0.0163, 승리횟수(Win count): 284, 승리비율(Win ratio): 58.4362
# 반복(Epoch): 486, 에러(err): 0.0088, 승리횟수(Win count): 285, 승리비율(Win ratio): 58.5216
# 반복(Epoch): 487, 에러(err): 0.0115, 승리횟수(Win count): 286, 승리비율(Win ratio): 58.6066
# 반복(Epoch): 488, 에러(err): 0.0169, 승리횟수(Win count): 287, 승리비율(Win ratio): 58.6912
# 반복(Epoch): 489, 에러(err): 0.0125, 승리횟수(Win count): 288, 승리비율(Win ratio): 58.7755
# 반복(Epoch): 490, 에러(err): 0.0129, 승리횟수(Win count): 289, 승리비율(Win ratio): 58.8595
# 반복(Epoch): 491, 에러(err): 0.0150, 승리횟수(Win count): 290, 승리비율(Win ratio): 58.9431
# 반복(Epoch): 492, 에러(err): 0.0083, 승리횟수(Win count): 291, 승리비율(Win ratio): 59.0264
# 반복(Epoch): 493, 에러(err): 0.0171, 승리횟수(Win count): 292, 승리비율(Win ratio): 59.1093
# 반복(Epoch): 494, 에러(err): 0.0079, 승리횟수(Win count): 293, 승리비율(Win ratio): 59.1919
# 반복(Epoch): 495, 에러(err): 0.0229, 승리횟수(Win count): 294, 승리비율(Win ratio): 59.2742
# 반복(Epoch): 496, 에러(err): 0.0204, 승리횟수(Win count): 295, 승리비율(Win ratio): 59.3561
# 반복(Epoch): 497, 에러(err): 0.0128, 승리횟수(Win count): 295, 승리비율(Win ratio): 59.2369
# 반복(Epoch): 498, 에러(err): 0.0166, 승리횟수(Win count): 296, 승리비율(Win ratio): 59.3186
# 반복(Epoch): 499, 에러(err): 0.0083, 승리횟수(Win count): 297, 승리비율(Win ratio): 59.4000
# 반복(Epoch): 500, 에러(err): 0.0078, 승리횟수(Win count): 298, 승리비율(Win ratio): 59.4810
# 반복(Epoch): 501, 에러(err): 0.0044, 승리횟수(Win count): 299, 승리비율(Win ratio): 59.5618
# /content/model.ckpt-501 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 502, 에러(err): 0.0030, 승리횟수(Win count): 299, 승리비율(Win ratio): 59.4433
# 반복(Epoch): 503, 에러(err): 0.0059, 승리횟수(Win count): 300, 승리비율(Win ratio): 59.5238
# 반복(Epoch): 504, 에러(err): 0.0098, 승리횟수(Win count): 301, 승리비율(Win ratio): 59.6040
# 반복(Epoch): 505, 에러(err): 0.0082, 승리횟수(Win count): 301, 승리비율(Win ratio): 59.4862
# 반복(Epoch): 506, 에러(err): 0.0112, 승리횟수(Win count): 301, 승리비율(Win ratio): 59.3688
# 반복(Epoch): 507, 에러(err): 0.0023, 승리횟수(Win count): 302, 승리비율(Win ratio): 59.4488
# 반복(Epoch): 508, 에러(err): 0.0037, 승리횟수(Win count): 303, 승리비율(Win ratio): 59.5285
# 반복(Epoch): 509, 에러(err): 0.0082, 승리횟수(Win count): 304, 승리비율(Win ratio): 59.6078
# 반복(Epoch): 510, 에러(err): 0.0029, 승리횟수(Win count): 305, 승리비율(Win ratio): 59.6869
# 반복(Epoch): 511, 에러(err): 0.0070, 승리횟수(Win count): 306, 승리비율(Win ratio): 59.7656
# 반복(Epoch): 512, 에러(err): 0.0031, 승리횟수(Win count): 307, 승리비율(Win ratio): 59.8441
# 반복(Epoch): 513, 에러(err): 0.0045, 승리횟수(Win count): 308, 승리비율(Win ratio): 59.9222
# 반복(Epoch): 514, 에러(err): 0.0041, 승리횟수(Win count): 308, 승리비율(Win ratio): 59.8058
# 반복(Epoch): 515, 에러(err): 0.0087, 승리횟수(Win count): 309, 승리비율(Win ratio): 59.8837
# 반복(Epoch): 516, 에러(err): 0.0097, 승리횟수(Win count): 310, 승리비율(Win ratio): 59.9613
# 반복(Epoch): 517, 에러(err): 0.0093, 승리횟수(Win count): 311, 승리비율(Win ratio): 60.0386
# 반복(Epoch): 518, 에러(err): 0.0062, 승리횟수(Win count): 312, 승리비율(Win ratio): 60.1156
# 반복(Epoch): 519, 에러(err): 0.0086, 승리횟수(Win count): 313, 승리비율(Win ratio): 60.1923
# 반복(Epoch): 520, 에러(err): 0.0047, 승리횟수(Win count): 313, 승리비율(Win ratio): 60.0768
# 반복(Epoch): 521, 에러(err): 0.0071, 승리횟수(Win count): 314, 승리비율(Win ratio): 60.1533
# 반복(Epoch): 522, 에러(err): 0.0049, 승리횟수(Win count): 315, 승리비율(Win ratio): 60.2294
# 반복(Epoch): 523, 에러(err): 0.0028, 승리횟수(Win count): 316, 승리비율(Win ratio): 60.3053
# 반복(Epoch): 524, 에러(err): 0.0025, 승리횟수(Win count): 317, 승리비율(Win ratio): 60.3810
# 반복(Epoch): 525, 에러(err): 0.0066, 승리횟수(Win count): 318, 승리비율(Win ratio): 60.4563
# 반복(Epoch): 526, 에러(err): 0.0199, 승리횟수(Win count): 319, 승리비율(Win ratio): 60.5313
# 반복(Epoch): 527, 에러(err): 0.0091, 승리횟수(Win count): 320, 승리비율(Win ratio): 60.6061
# 반복(Epoch): 528, 에러(err): 0.0116, 승리횟수(Win count): 321, 승리비율(Win ratio): 60.6805
# 반복(Epoch): 529, 에러(err): 0.0063, 승리횟수(Win count): 322, 승리비율(Win ratio): 60.7547
# 반복(Epoch): 530, 에러(err): 0.0025, 승리횟수(Win count): 323, 승리비율(Win ratio): 60.8286
# 반복(Epoch): 531, 에러(err): 0.0028, 승리횟수(Win count): 323, 승리비율(Win ratio): 60.7143
# 반복(Epoch): 532, 에러(err): 0.0024, 승리횟수(Win count): 324, 승리비율(Win ratio): 60.7880
# 반복(Epoch): 533, 에러(err): 0.0054, 승리횟수(Win count): 325, 승리비율(Win ratio): 60.8614
# 반복(Epoch): 534, 에러(err): 0.0052, 승리횟수(Win count): 326, 승리비율(Win ratio): 60.9346
# 반복(Epoch): 535, 에러(err): 0.0034, 승리횟수(Win count): 327, 승리비율(Win ratio): 61.0075
# 반복(Epoch): 536, 에러(err): 0.0097, 승리횟수(Win count): 328, 승리비율(Win ratio): 61.0801
# 반복(Epoch): 537, 에러(err): 0.0080, 승리횟수(Win count): 329, 승리비율(Win ratio): 61.1524
# 반복(Epoch): 538, 에러(err): 0.0077, 승리횟수(Win count): 329, 승리비율(Win ratio): 61.0390
# 반복(Epoch): 539, 에러(err): 0.0020, 승리횟수(Win count): 330, 승리비율(Win ratio): 61.1111
# 반복(Epoch): 540, 에러(err): 0.0039, 승리횟수(Win count): 331, 승리비율(Win ratio): 61.1830
# 반복(Epoch): 541, 에러(err): 0.0086, 승리횟수(Win count): 332, 승리비율(Win ratio): 61.2546
# 반복(Epoch): 542, 에러(err): 0.0040, 승리횟수(Win count): 333, 승리비율(Win ratio): 61.3260
# 반복(Epoch): 543, 에러(err): 0.0020, 승리횟수(Win count): 333, 승리비율(Win ratio): 61.2132
# 반복(Epoch): 544, 에러(err): 0.0050, 승리횟수(Win count): 334, 승리비율(Win ratio): 61.2844
# 반복(Epoch): 545, 에러(err): 0.0057, 승리횟수(Win count): 335, 승리비율(Win ratio): 61.3553
# 반복(Epoch): 546, 에러(err): 0.0029, 승리횟수(Win count): 336, 승리비율(Win ratio): 61.4260
# 반복(Epoch): 547, 에러(err): 0.0017, 승리횟수(Win count): 337, 승리비율(Win ratio): 61.4964
# 반복(Epoch): 548, 에러(err): 0.0021, 승리횟수(Win count): 338, 승리비율(Win ratio): 61.5665
# 반복(Epoch): 549, 에러(err): 0.0119, 승리횟수(Win count): 339, 승리비율(Win ratio): 61.6364
# 반복(Epoch): 550, 에러(err): 0.0060, 승리횟수(Win count): 339, 승리비율(Win ratio): 61.5245
# 반복(Epoch): 551, 에러(err): 0.0038, 승리횟수(Win count): 340, 승리비율(Win ratio): 61.5942
# 반복(Epoch): 552, 에러(err): 0.0022, 승리횟수(Win count): 341, 승리비율(Win ratio): 61.6637
# 반복(Epoch): 553, 에러(err): 0.0030, 승리횟수(Win count): 342, 승리비율(Win ratio): 61.7329
# 반복(Epoch): 554, 에러(err): 0.0032, 승리횟수(Win count): 343, 승리비율(Win ratio): 61.8018
# ...
# 반복(Epoch): 803, 에러(err): 0.0081, 승리횟수(Win count): 553, 승리비율(Win ratio): 68.7811
# 반복(Epoch): 804, 에러(err): 0.0100, 승리횟수(Win count): 554, 승리비율(Win ratio): 68.8199
# 반복(Epoch): 805, 에러(err): 0.0038, 승리횟수(Win count): 555, 승리비율(Win ratio): 68.8586
# 반복(Epoch): 806, 에러(err): 0.0064, 승리횟수(Win count): 555, 승리비율(Win ratio): 68.7732
# 반복(Epoch): 807, 에러(err): 0.0259, 승리횟수(Win count): 556, 승리비율(Win ratio): 68.8119
# 반복(Epoch): 808, 에러(err): 0.0078, 승리횟수(Win count): 557, 승리비율(Win ratio): 68.8504
# 반복(Epoch): 809, 에러(err): 0.0109, 승리횟수(Win count): 558, 승리비율(Win ratio): 68.8889
# 반복(Epoch): 810, 에러(err): 0.0434, 승리횟수(Win count): 559, 승리비율(Win ratio): 68.9273
# 반복(Epoch): 811, 에러(err): 0.0239, 승리횟수(Win count): 560, 승리비율(Win ratio): 68.9655
# 반복(Epoch): 812, 에러(err): 0.0535, 승리횟수(Win count): 561, 승리비율(Win ratio): 69.0037
# 반복(Epoch): 813, 에러(err): 0.0112, 승리횟수(Win count): 562, 승리비율(Win ratio): 69.0418
# 반복(Epoch): 814, 에러(err): 0.0102, 승리횟수(Win count): 563, 승리비율(Win ratio): 69.0798
# 반복(Epoch): 815, 에러(err): 0.0036, 승리횟수(Win count): 564, 승리비율(Win ratio): 69.1176
# 반복(Epoch): 816, 에러(err): 0.0067, 승리횟수(Win count): 564, 승리비율(Win ratio): 69.0330
# 반복(Epoch): 817, 에러(err): 0.0048, 승리횟수(Win count): 565, 승리비율(Win ratio): 69.0709
# 반복(Epoch): 818, 에러(err): 0.0551, 승리횟수(Win count): 566, 승리비율(Win ratio): 69.1087
# 반복(Epoch): 819, 에러(err): 0.0375, 승리횟수(Win count): 567, 승리비율(Win ratio): 69.1463
# 반복(Epoch): 820, 에러(err): 0.0374, 승리횟수(Win count): 568, 승리비율(Win ratio): 69.1839
# 반복(Epoch): 821, 에러(err): 0.0238, 승리횟수(Win count): 569, 승리비율(Win ratio): 69.2214
# 반복(Epoch): 822, 에러(err): 0.0249, 승리횟수(Win count): 570, 승리비율(Win ratio): 69.2588
# 반복(Epoch): 823, 에러(err): 0.0276, 승리횟수(Win count): 570, 승리비율(Win ratio): 69.1748
# 반복(Epoch): 824, 에러(err): 0.0426, 승리횟수(Win count): 571, 승리비율(Win ratio): 69.2121
# 반복(Epoch): 825, 에러(err): 0.0375, 승리횟수(Win count): 572, 승리비율(Win ratio): 69.2494
# 반복(Epoch): 826, 에러(err): 0.0245, 승리횟수(Win count): 573, 승리비율(Win ratio): 69.2866
# 반복(Epoch): 827, 에러(err): 0.0287, 승리횟수(Win count): 574, 승리비율(Win ratio): 69.3237
# 반복(Epoch): 828, 에러(err): 0.0150, 승리횟수(Win count): 575, 승리비율(Win ratio): 69.3607
# 반복(Epoch): 829, 에러(err): 0.0096, 승리횟수(Win count): 576, 승리비율(Win ratio): 69.3976
# 반복(Epoch): 830, 에러(err): 0.0412, 승리횟수(Win count): 576, 승리비율(Win ratio): 69.3141
# 반복(Epoch): 831, 에러(err): 0.0195, 승리횟수(Win count): 577, 승리비율(Win ratio): 69.3510
# 반복(Epoch): 832, 에러(err): 0.0130, 승리횟수(Win count): 578, 승리비율(Win ratio): 69.3878
# 반복(Epoch): 833, 에러(err): 0.0271, 승리횟수(Win count): 579, 승리비율(Win ratio): 69.4245
# 반복(Epoch): 834, 에러(err): 0.1107, 승리횟수(Win count): 580, 승리비율(Win ratio): 69.4611
# 반복(Epoch): 835, 에러(err): 0.0308, 승리횟수(Win count): 581, 승리비율(Win ratio): 69.4976
# 반복(Epoch): 836, 에러(err): 0.0163, 승리횟수(Win count): 581, 승리비율(Win ratio): 69.4146
# 반복(Epoch): 837, 에러(err): 0.0110, 승리횟수(Win count): 582, 승리비율(Win ratio): 69.4511
# 반복(Epoch): 838, 에러(err): 0.0094, 승리횟수(Win count): 583, 승리비율(Win ratio): 69.4875
# 반복(Epoch): 839, 에러(err): 0.0134, 승리횟수(Win count): 584, 승리비율(Win ratio): 69.5238
# 반복(Epoch): 840, 에러(err): 0.0180, 승리횟수(Win count): 584, 승리비율(Win ratio): 69.4411
# 반복(Epoch): 841, 에러(err): 0.0188, 승리횟수(Win count): 585, 승리비율(Win ratio): 69.4774
# 반복(Epoch): 842, 에러(err): 0.0147, 승리횟수(Win count): 586, 승리비율(Win ratio): 69.5136
# 반복(Epoch): 843, 에러(err): 0.0275, 승리횟수(Win count): 587, 승리비율(Win ratio): 69.5498
# 반복(Epoch): 844, 에러(err): 0.0195, 승리횟수(Win count): 588, 승리비율(Win ratio): 69.5858
# 반복(Epoch): 845, 에러(err): 0.0133, 승리횟수(Win count): 588, 승리비율(Win ratio): 69.5035
# 반복(Epoch): 846, 에러(err): 0.0288, 승리횟수(Win count): 589, 승리비율(Win ratio): 69.5396
# 반복(Epoch): 847, 에러(err): 0.0597, 승리횟수(Win count): 589, 승리비율(Win ratio): 69.4575
# 반복(Epoch): 848, 에러(err): 0.0452, 승리횟수(Win count): 590, 승리비율(Win ratio): 69.4935
# 반복(Epoch): 849, 에러(err): 0.0256, 승리횟수(Win count): 591, 승리비율(Win ratio): 69.5294
# 반복(Epoch): 850, 에러(err): 0.0237, 승리횟수(Win count): 591, 승리비율(Win ratio): 69.4477
# 반복(Epoch): 851, 에러(err): 0.0219, 승리횟수(Win count): 592, 승리비율(Win ratio): 69.4836
# 반복(Epoch): 852, 에러(err): 0.0615, 승리횟수(Win count): 593, 승리비율(Win ratio): 69.5193
# 반복(Epoch): 853, 에러(err): 0.0280, 승리횟수(Win count): 594, 승리비율(Win ratio): 69.5550
# 반복(Epoch): 854, 에러(err): 0.0146, 승리횟수(Win count): 595, 승리비율(Win ratio): 69.5906
# 반복(Epoch): 855, 에러(err): 0.0367, 승리횟수(Win count): 596, 승리비율(Win ratio): 69.6262
# 반복(Epoch): 856, 에러(err): 0.0212, 승리횟수(Win count): 597, 승리비율(Win ratio): 69.6616
# 반복(Epoch): 857, 에러(err): 0.0194, 승리횟수(Win count): 598, 승리비율(Win ratio): 69.6970
# 반복(Epoch): 858, 에러(err): 0.0764, 승리횟수(Win count): 599, 승리비율(Win ratio): 69.7322
# 반복(Epoch): 859, 에러(err): 0.0177, 승리횟수(Win count): 600, 승리비율(Win ratio): 69.7674
# 반복(Epoch): 860, 에러(err): 0.0644, 승리횟수(Win count): 600, 승리비율(Win ratio): 69.6864
# 반복(Epoch): 861, 에러(err): 0.0479, 승리횟수(Win count): 601, 승리비율(Win ratio): 69.7216
# 반복(Epoch): 862, 에러(err): 0.0462, 승리횟수(Win count): 602, 승리비율(Win ratio): 69.7567
# 반복(Epoch): 863, 에러(err): 0.0157, 승리횟수(Win count): 603, 승리비율(Win ratio): 69.7917
# 반복(Epoch): 864, 에러(err): 0.0380, 승리횟수(Win count): 604, 승리비율(Win ratio): 69.8266
# 반복(Epoch): 865, 에러(err): 0.0373, 승리횟수(Win count): 604, 승리비율(Win ratio): 69.7460
# 반복(Epoch): 866, 에러(err): 0.0147, 승리횟수(Win count): 605, 승리비율(Win ratio): 69.7809
# 반복(Epoch): 867, 에러(err): 0.0317, 승리횟수(Win count): 605, 승리비율(Win ratio): 69.7005
# 반복(Epoch): 868, 에러(err): 0.0238, 승리횟수(Win count): 606, 승리비율(Win ratio): 69.7353
# 반복(Epoch): 869, 에러(err): 0.0428, 승리횟수(Win count): 607, 승리비율(Win ratio): 69.7701
# 반복(Epoch): 870, 에러(err): 0.0169, 승리횟수(Win count): 608, 승리비율(Win ratio): 69.8048
# 반복(Epoch): 871, 에러(err): 0.0061, 승리횟수(Win count): 609, 승리비율(Win ratio): 69.8394
# 반복(Epoch): 872, 에러(err): 0.0137, 승리횟수(Win count): 610, 승리비율(Win ratio): 69.8740
# 반복(Epoch): 873, 에러(err): 0.0340, 승리횟수(Win count): 611, 승리비율(Win ratio): 69.9085
# 반복(Epoch): 874, 에러(err): 0.0162, 승리횟수(Win count): 612, 승리비율(Win ratio): 69.9429
# 반복(Epoch): 875, 에러(err): 0.0289, 승리횟수(Win count): 612, 승리비율(Win ratio): 69.8630
# 반복(Epoch): 876, 에러(err): 0.0143, 승리횟수(Win count): 613, 승리비율(Win ratio): 69.8974
# 반복(Epoch): 877, 에러(err): 0.0107, 승리횟수(Win count): 614, 승리비율(Win ratio): 69.9317
# 반복(Epoch): 878, 에러(err): 0.0144, 승리횟수(Win count): 615, 승리비율(Win ratio): 69.9659
# 반복(Epoch): 879, 에러(err): 0.0203, 승리횟수(Win count): 616, 승리비율(Win ratio): 70.0000
# 반복(Epoch): 880, 에러(err): 0.0323, 승리횟수(Win count): 617, 승리비율(Win ratio): 70.0341
# 반복(Epoch): 881, 에러(err): 0.0138, 승리횟수(Win count): 618, 승리비율(Win ratio): 70.0680
# 반복(Epoch): 882, 에러(err): 0.0110, 승리횟수(Win count): 619, 승리비율(Win ratio): 70.1019
# 반복(Epoch): 883, 에러(err): 0.0126, 승리횟수(Win count): 620, 승리비율(Win ratio): 70.1357
# 반복(Epoch): 884, 에러(err): 0.0150, 승리횟수(Win count): 621, 승리비율(Win ratio): 70.1695
# 반복(Epoch): 885, 에러(err): 0.0100, 승리횟수(Win count): 621, 승리비율(Win ratio): 70.0903
# 반복(Epoch): 886, 에러(err): 0.0092, 승리횟수(Win count): 622, 승리비율(Win ratio): 70.1240
# 반복(Epoch): 887, 에러(err): 0.0093, 승리횟수(Win count): 623, 승리비율(Win ratio): 70.1577
# 반복(Epoch): 888, 에러(err): 0.0066, 승리횟수(Win count): 624, 승리비율(Win ratio): 70.1912
# 반복(Epoch): 889, 에러(err): 0.0144, 승리횟수(Win count): 625, 승리비율(Win ratio): 70.2247
# 반복(Epoch): 890, 에러(err): 0.0103, 승리횟수(Win count): 625, 승리비율(Win ratio): 70.1459
# 반복(Epoch): 891, 에러(err): 0.0062, 승리횟수(Win count): 626, 승리비율(Win ratio): 70.1794
# 반복(Epoch): 892, 에러(err): 0.0128, 승리횟수(Win count): 627, 승리비율(Win ratio): 70.2128
# 반복(Epoch): 893, 에러(err): 0.0110, 승리횟수(Win count): 628, 승리비율(Win ratio): 70.2461
# 반복(Epoch): 894, 에러(err): 0.0131, 승리횟수(Win count): 629, 승리비율(Win ratio): 70.2793
# 반복(Epoch): 895, 에러(err): 0.0065, 승리횟수(Win count): 630, 승리비율(Win ratio): 70.3125
# 반복(Epoch): 896, 에러(err): 0.0249, 승리횟수(Win count): 631, 승리비율(Win ratio): 70.3456
# 반복(Epoch): 897, 에러(err): 0.0047, 승리횟수(Win count): 632, 승리비율(Win ratio): 70.3786
# 반복(Epoch): 898, 에러(err): 0.0086, 승리횟수(Win count): 633, 승리비율(Win ratio): 70.4116
# 반복(Epoch): 899, 에러(err): 0.0193, 승리횟수(Win count): 634, 승리비율(Win ratio): 70.4444
# 반복(Epoch): 900, 에러(err): 0.0189, 승리횟수(Win count): 635, 승리비율(Win ratio): 70.4772
# 반복(Epoch): 901, 에러(err): 0.0144, 승리횟수(Win count): 636, 승리비율(Win ratio): 70.5100
# /content/model.ckpt-901 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 902, 에러(err): 0.0058, 승리횟수(Win count): 637, 승리비율(Win ratio): 70.5426
# 반복(Epoch): 903, 에러(err): 0.0097, 승리횟수(Win count): 638, 승리비율(Win ratio): 70.5752
# 반복(Epoch): 904, 에러(err): 0.0111, 승리횟수(Win count): 639, 승리비율(Win ratio): 70.6077
# 반복(Epoch): 905, 에러(err): 0.0083, 승리횟수(Win count): 640, 승리비율(Win ratio): 70.6402
# 반복(Epoch): 906, 에러(err): 0.0080, 승리횟수(Win count): 641, 승리비율(Win ratio): 70.6725
# 반복(Epoch): 907, 에러(err): 0.0089, 승리횟수(Win count): 642, 승리비율(Win ratio): 70.7048
# 반복(Epoch): 908, 에러(err): 0.0060, 승리횟수(Win count): 643, 승리비율(Win ratio): 70.7371
# 반복(Epoch): 909, 에러(err): 0.0027, 승리횟수(Win count): 644, 승리비율(Win ratio): 70.7692
# 반복(Epoch): 910, 에러(err): 0.0028, 승리횟수(Win count): 644, 승리비율(Win ratio): 70.6915
# 반복(Epoch): 911, 에러(err): 0.0055, 승리횟수(Win count): 645, 승리비율(Win ratio): 70.7237
# 반복(Epoch): 912, 에러(err): 0.0038, 승리횟수(Win count): 646, 승리비율(Win ratio): 70.7558
# 반복(Epoch): 913, 에러(err): 0.0019, 승리횟수(Win count): 647, 승리비율(Win ratio): 70.7877
# 반복(Epoch): 914, 에러(err): 0.0037, 승리횟수(Win count): 648, 승리비율(Win ratio): 70.8197
# 반복(Epoch): 915, 에러(err): 0.0051, 승리횟수(Win count): 648, 승리비율(Win ratio): 70.7424
# 반복(Epoch): 916, 에러(err): 0.0056, 승리횟수(Win count): 649, 승리비율(Win ratio): 70.7743
# 반복(Epoch): 917, 에러(err): 0.0079, 승리횟수(Win count): 649, 승리비율(Win ratio): 70.6972
# 반복(Epoch): 918, 에러(err): 0.0133, 승리횟수(Win count): 650, 승리비율(Win ratio): 70.7291
# 반복(Epoch): 919, 에러(err): 0.0038, 승리횟수(Win count): 651, 승리비율(Win ratio): 70.7609
# 반복(Epoch): 920, 에러(err): 0.0093, 승리횟수(Win count): 652, 승리비율(Win ratio): 70.7926
# 반복(Epoch): 921, 에러(err): 0.0177, 승리횟수(Win count): 653, 승리비율(Win ratio): 70.8243
# 반복(Epoch): 922, 에러(err): 0.0118, 승리횟수(Win count): 654, 승리비율(Win ratio): 70.8559
# 반복(Epoch): 923, 에러(err): 0.0038, 승리횟수(Win count): 655, 승리비율(Win ratio): 70.8874
# 반복(Epoch): 924, 에러(err): 0.0060, 승리횟수(Win count): 656, 승리비율(Win ratio): 70.9189
# 반복(Epoch): 925, 에러(err): 0.0096, 승리횟수(Win count): 657, 승리비율(Win ratio): 70.9503
# 반복(Epoch): 926, 에러(err): 0.0034, 승리횟수(Win count): 658, 승리비율(Win ratio): 70.9817
# 반복(Epoch): 927, 에러(err): 0.0034, 승리횟수(Win count): 659, 승리비율(Win ratio): 71.0129
# 반복(Epoch): 928, 에러(err): 0.0046, 승리횟수(Win count): 660, 승리비율(Win ratio): 71.0441
# 반복(Epoch): 929, 에러(err): 0.0091, 승리횟수(Win count): 661, 승리비율(Win ratio): 71.0753
# 반복(Epoch): 930, 에러(err): 0.0032, 승리횟수(Win count): 662, 승리비율(Win ratio): 71.1063
# 반복(Epoch): 931, 에러(err): 0.0041, 승리횟수(Win count): 663, 승리비율(Win ratio): 71.1373
# 반복(Epoch): 932, 에러(err): 0.0035, 승리횟수(Win count): 664, 승리비율(Win ratio): 71.1683
# 반복(Epoch): 933, 에러(err): 0.0023, 승리횟수(Win count): 665, 승리비율(Win ratio): 71.1991
# 반복(Epoch): 934, 에러(err): 0.0033, 승리횟수(Win count): 666, 승리비율(Win ratio): 71.2299
# 반복(Epoch): 935, 에러(err): 0.0045, 승리횟수(Win count): 667, 승리비율(Win ratio): 71.2607
# 반복(Epoch): 936, 에러(err): 0.0033, 승리횟수(Win count): 668, 승리비율(Win ratio): 71.2914
# 반복(Epoch): 937, 에러(err): 0.0068, 승리횟수(Win count): 669, 승리비율(Win ratio): 71.3220
# 반복(Epoch): 938, 에러(err): 0.0033, 승리횟수(Win count): 670, 승리비율(Win ratio): 71.3525
# 반복(Epoch): 939, 에러(err): 0.0056, 승리횟수(Win count): 671, 승리비율(Win ratio): 71.3830
# 반복(Epoch): 940, 에러(err): 0.0077, 승리횟수(Win count): 672, 승리비율(Win ratio): 71.4134
# 반복(Epoch): 941, 에러(err): 0.0044, 승리횟수(Win count): 673, 승리비율(Win ratio): 71.4437
# 반복(Epoch): 942, 에러(err): 0.0032, 승리횟수(Win count): 674, 승리비율(Win ratio): 71.4740
# 반복(Epoch): 943, 에러(err): 0.0028, 승리횟수(Win count): 675, 승리비율(Win ratio): 71.5042
# 반복(Epoch): 944, 에러(err): 0.0023, 승리횟수(Win count): 676, 승리비율(Win ratio): 71.5344
# 반복(Epoch): 945, 에러(err): 0.0031, 승리횟수(Win count): 677, 승리비율(Win ratio): 71.5645
# 반복(Epoch): 946, 에러(err): 0.0039, 승리횟수(Win count): 678, 승리비율(Win ratio): 71.5945
# 반복(Epoch): 947, 에러(err): 0.0032, 승리횟수(Win count): 679, 승리비율(Win ratio): 71.6245
# 반복(Epoch): 948, 에러(err): 0.0047, 승리횟수(Win count): 680, 승리비율(Win ratio): 71.6544
# 반복(Epoch): 949, 에러(err): 0.0074, 승리횟수(Win count): 681, 승리비율(Win ratio): 71.6842
# 반복(Epoch): 950, 에러(err): 0.0052, 승리횟수(Win count): 682, 승리비율(Win ratio): 71.7140
# 반복(Epoch): 951, 에러(err): 0.0345, 승리횟수(Win count): 683, 승리비율(Win ratio): 71.7437
# 반복(Epoch): 952, 에러(err): 0.0656, 승리횟수(Win count): 684, 승리비율(Win ratio): 71.7733
# 반복(Epoch): 953, 에러(err): 0.0283, 승리횟수(Win count): 685, 승리비율(Win ratio): 71.8029
# 반복(Epoch): 954, 에러(err): 0.0090, 승리횟수(Win count): 686, 승리비율(Win ratio): 71.8325
# 반복(Epoch): 955, 에러(err): 0.0122, 승리횟수(Win count): 687, 승리비율(Win ratio): 71.8619
# 반복(Epoch): 956, 에러(err): 0.0260, 승리횟수(Win count): 687, 승리비율(Win ratio): 71.7868
# 반복(Epoch): 957, 에러(err): 0.0095, 승리횟수(Win count): 688, 승리비율(Win ratio): 71.8163
# 반복(Epoch): 958, 에러(err): 0.0302, 승리횟수(Win count): 689, 승리비율(Win ratio): 71.8457
# 반복(Epoch): 959, 에러(err): 0.0207, 승리횟수(Win count): 689, 승리비율(Win ratio): 71.7708
# 반복(Epoch): 960, 에러(err): 0.0306, 승리횟수(Win count): 690, 승리비율(Win ratio): 71.8002
# 반복(Epoch): 961, 에러(err): 0.0229, 승리횟수(Win count): 691, 승리비율(Win ratio): 71.8295
# 반복(Epoch): 962, 에러(err): 0.0266, 승리횟수(Win count): 692, 승리비율(Win ratio): 71.8588
# 반복(Epoch): 963, 에러(err): 0.0500, 승리횟수(Win count): 693, 승리비율(Win ratio): 71.8880
# 반복(Epoch): 964, 에러(err): 0.0702, 승리횟수(Win count): 694, 승리비율(Win ratio): 71.9171
# 반복(Epoch): 965, 에러(err): 0.0582, 승리횟수(Win count): 695, 승리비율(Win ratio): 71.9462
# 반복(Epoch): 966, 에러(err): 0.0197, 승리횟수(Win count): 696, 승리비율(Win ratio): 71.9752
# 반복(Epoch): 967, 에러(err): 0.0258, 승리횟수(Win count): 697, 승리비율(Win ratio): 72.0041
# 반복(Epoch): 968, 에러(err): 0.0179, 승리횟수(Win count): 698, 승리비율(Win ratio): 72.0330
# 반복(Epoch): 969, 에러(err): 0.0177, 승리횟수(Win count): 699, 승리비율(Win ratio): 72.0619
# 반복(Epoch): 970, 에러(err): 0.0309, 승리횟수(Win count): 700, 승리비율(Win ratio): 72.0906
# 반복(Epoch): 971, 에러(err): 0.0201, 승리횟수(Win count): 701, 승리비율(Win ratio): 72.1193
# 반복(Epoch): 972, 에러(err): 0.0133, 승리횟수(Win count): 702, 승리비율(Win ratio): 72.1480
# 반복(Epoch): 973, 에러(err): 0.0260, 승리횟수(Win count): 703, 승리비율(Win ratio): 72.1766
# 반복(Epoch): 974, 에러(err): 0.0138, 승리횟수(Win count): 704, 승리비율(Win ratio): 72.2051
# 반복(Epoch): 975, 에러(err): 0.0126, 승리횟수(Win count): 705, 승리비율(Win ratio): 72.2336
# 반복(Epoch): 976, 에러(err): 0.0062, 승리횟수(Win count): 706, 승리비율(Win ratio): 72.2620
# 반복(Epoch): 977, 에러(err): 0.0197, 승리횟수(Win count): 707, 승리비율(Win ratio): 72.2904
# 반복(Epoch): 978, 에러(err): 0.0068, 승리횟수(Win count): 708, 승리비율(Win ratio): 72.3187
# 반복(Epoch): 979, 에러(err): 0.0161, 승리횟수(Win count): 709, 승리비율(Win ratio): 72.3469
# 반복(Epoch): 980, 에러(err): 0.0243, 승리횟수(Win count): 710, 승리비율(Win ratio): 72.3751
# 반복(Epoch): 981, 에러(err): 0.0076, 승리횟수(Win count): 711, 승리비율(Win ratio): 72.4033
# 반복(Epoch): 982, 에러(err): 0.0073, 승리횟수(Win count): 712, 승리비율(Win ratio): 72.4313
# 반복(Epoch): 983, 에러(err): 0.0087, 승리횟수(Win count): 713, 승리비율(Win ratio): 72.4593
# 반복(Epoch): 984, 에러(err): 0.0151, 승리횟수(Win count): 714, 승리비율(Win ratio): 72.4873
# 반복(Epoch): 985, 에러(err): 0.0085, 승리횟수(Win count): 715, 승리비율(Win ratio): 72.5152
# 반복(Epoch): 986, 에러(err): 0.0057, 승리횟수(Win count): 716, 승리비율(Win ratio): 72.5431
# 반복(Epoch): 987, 에러(err): 0.0110, 승리횟수(Win count): 717, 승리비율(Win ratio): 72.5709
# 반복(Epoch): 988, 에러(err): 0.0068, 승리횟수(Win count): 718, 승리비율(Win ratio): 72.5986
# 반복(Epoch): 989, 에러(err): 0.0086, 승리횟수(Win count): 718, 승리비율(Win ratio): 72.5253
# 반복(Epoch): 990, 에러(err): 0.0125, 승리횟수(Win count): 719, 승리비율(Win ratio): 72.5530
# 반복(Epoch): 991, 에러(err): 0.0109, 승리횟수(Win count): 720, 승리비율(Win ratio): 72.5806
# 반복(Epoch): 992, 에러(err): 0.0066, 승리횟수(Win count): 720, 승리비율(Win ratio): 72.5076
# 반복(Epoch): 993, 에러(err): 0.0111, 승리횟수(Win count): 721, 승리비율(Win ratio): 72.5352
# 반복(Epoch): 994, 에러(err): 0.0064, 승리횟수(Win count): 722, 승리비율(Win ratio): 72.5628
# 반복(Epoch): 995, 에러(err): 0.0075, 승리횟수(Win count): 723, 승리비율(Win ratio): 72.5904
# 반복(Epoch): 996, 에러(err): 0.0051, 승리횟수(Win count): 724, 승리비율(Win ratio): 72.6179
# 반복(Epoch): 997, 에러(err): 0.0054, 승리횟수(Win count): 725, 승리비율(Win ratio): 72.6453
# 반복(Epoch): 998, 에러(err): 0.0033, 승리횟수(Win count): 726, 승리비율(Win ratio): 72.6727
# 반복(Epoch): 999, 에러(err): 0.0067, 승리횟수(Win count): 727, 승리비율(Win ratio): 72.7000
# 반복(Epoch): 1000, 에러(err): 0.0137, 승리횟수(Win count): 728, 승리비율(Win ratio): 72.7273
# 트레이닝 완료
# /content/model.ckpt-1000 경로에 파라미터가 저장되었습니다

# %%
from Chap_12_Reinforced_Learning_Training import CatchEnvironment, DQN
from IPython import display
import matplotlib.patches as patches
import pylab as pl
import time
import tensorflow as tf
import os

# %%
# 설정값들을 정의합니다.
gridSize = 10
maxGames = 30
DQN_model = DQN()
env = CatchEnvironment(gridSize)
winCount = 0
loseCount = 0
numberOfGames = 0

# %%
# 현재 상태를 그리기 위한 drawState 함수를 정의합니다.
def drawState(fruitRow, fruitColumn, basket, gridSize):
  # 과일이 몇번째 세로축에 있는지 정의합니다.
  fruitX = fruitColumn 
  # 과일이 몇번째 가로축에 있는지 정의합니다.
  fruitY = (gridSize - fruitRow + 1)
  # 승리 횟수, 패배 횟수, 전체 게임 횟수를 화면 상단에 출력합니다.
  statusTitle = "Wins: " + str(winCount) + "  Losses: " + str(loseCount) + "  TotalGame: " + str(numberOfGames)
  axis.set_title(statusTitle, fontsize=30)
  for p in [
    # 배경의 위치를 지정합니다.
    patches.Rectangle(
        ((ground - 1), (ground)), 11, 10,
        facecolor="#000000"      # Black
    ),
    # 바구니의 위치를 지정합니다.
    patches.Rectangle(
        (basket - 1, ground), 2, 0.5,
        facecolor="#FF0000"     # Red
    ),
    # 과일의 위치를 지정합니다.
    patches.Rectangle(
        (fruitX - 0.5, fruitY - 0.5), 1, 1,
        facecolor="#0000FF"       # Blue
    ),   
    ]:
      axis.add_patch(p)
  display.clear_output(wait=True)
  display.display(pl.gcf())

# %%
# 저장된 파라미터를 불러옵니다.
ckpt = tf.train.Checkpoint(model=DQN_model)
latest_ckpt = tf.train.latest_checkpoint(os.getcwd())
#latest_ckpt = '/content/model.ckpt-201'

ckpt.restore(latest_ckpt)

print('저장된 파라미터를 불러왔습니다!')
# Out:
# 저장된 파라미터를 불러왔습니다!

# %%
# GIF를 만들기위해 설치합니다.
# !pip install imageio

# !mkdir '/content/generated_output/'

import glob
import imageio
import matplotlib.pyplot as plt
import PIL

def display_image(epoch_no):
  return PIL.Image.open('/content/generated_output/image_at_epoch_{:04d}.png'.format(epoch_no))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.22.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (8.4.0)
# mkdir: cannot create directory ‘/content/generated_output/’: File exists

# %%
# 화면을 그리기 위한 설정들을 정의합니다.
ground = 1
plot = pl.figure(figsize=(12,12))
axis = plot.add_subplot(111, aspect='equal')
axis.set_xlim([-1, 12])
axis.set_ylim([0, 12])

frame = 1

# maxGames 횟수만큼 게임을 플레이합니다.
while (numberOfGames < maxGames):
  numberOfGames = numberOfGames + 1

  # 최초의 상태를 정의합니다.
  isGameOver = False
  fruitRow, fruitColumn, basket = env.reset()
  currentState = env.observe()
  drawState(fruitRow, fruitColumn, basket, gridSize)

  while (isGameOver != True):
    # 현재 상태를 DQN의 입력값으로 넣고 구한 Q값중 가장 큰 Q값을 갖는 행동을 취합니다.
    q = DQN_model(currentState).numpy()
    action = q.argmax()

    # 행동을 취하고 다음 상태로 넘어갑니다.
    nextState, reward, gameOver, stateInfo = env.act(action)    
    fruitRow = stateInfo[0]
    fruitColumn = stateInfo[1]
    basket = stateInfo[2]
     
    # 과일을 받아내면 winCount를 1 늘리고 과일을 받아내지 못하면 loseCount를 1 늘립니다.
    if (reward == 1):
      winCount = winCount + 1
    elif (reward == -1):
      loseCount = loseCount + 1

    currentState = nextState
    isGameOver = gameOver
    drawState(fruitRow, fruitColumn, basket, gridSize)
    # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#    time.sleep(5)
    plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
    frame = frame+1

# 최종 출력결과 이미지를 하나로 정리합니다.
display.clear_output(wait=True)

# %%
anim_file = '/content/generated_output/dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/generated_output/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)
# Out:
# <ipython-input-50-7c43f235b718>:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# <ipython-input-50-7c43f235b718>:15: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %%
from google.colab import files

files.download(anim_file)
# !zip -r /content/file.zip /content/generated_output
files.download("/content/file.zip")
# Out:
# updating: content/generated_output/ (stored 0%)
# updating: content/generated_output/image_at_frame_0028.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0015.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0031.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0119.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0036.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0129.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0140.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0027.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0131.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0122.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0042.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0096.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0056.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0072.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0159.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0083.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0136.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0022.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0176.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0059.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0150.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0182.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0203.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0126.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0013.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0127.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0046.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0222.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0064.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0133.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0227.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0039.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0197.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0071.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0125.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0100.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0043.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0113.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0214.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0169.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0107.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0102.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0137.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0199.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0196.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0079.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0151.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0110.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0141.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0193.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0051.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0115.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0097.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0121.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0158.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0058.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0234.png (deflated 34%)
# updating: content/generated_output/image_at_frame_0063.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0215.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0016.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0228.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0106.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0204.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0194.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0239.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0200.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0026.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0218.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0099.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0108.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0098.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0095.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0070.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0237.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0225.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0224.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0065.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0212.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0233.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0105.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0005.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0220.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0112.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0103.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0139.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0080.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0060.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0135.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0068.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0117.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0094.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0062.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0145.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0053.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0057.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0154.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0198.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0008.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0104.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0138.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0033.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0124.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0206.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0157.png (deflated 35%)
# updating: content/generated_output/dcgan.gif (deflated 19%)
# updating: content/generated_output/image_at_frame_0073.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0003.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0032.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0086.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0077.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0238.png (deflated 34%)
# updating: content/generated_output/image_at_frame_0168.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0209.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0210.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0055.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0052.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0226.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0240.png (deflated 34%)
# updating: content/generated_output/image_at_frame_0221.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0084.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0164.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0144.png (deflated 34%)
# updating: content/generated_output/image_at_frame_0236.png (deflated 34%)
# updating: content/generated_output/image_at_frame_0123.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0090.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0017.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0189.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0167.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0006.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0175.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0061.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0170.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0002.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0029.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0166.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0091.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0012.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0174.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0118.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0035.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0007.png (deflated 38%)
# updating: content/generated_output/image_at_frame_0190.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0128.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0038.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0087.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0069.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0066.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0161.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0019.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0089.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0185.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0049.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0179.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0192.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0030.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0186.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0134.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0082.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0074.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0231.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0054.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0172.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0230.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0149.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0208.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0232.png (deflated 34%)
# updating: content/generated_output/image_at_frame_0147.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0184.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0207.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0171.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0010.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0195.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0034.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0114.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0085.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0021.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0111.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0088.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0024.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0045.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0130.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0146.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0025.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0116.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0076.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0092.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0213.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0219.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0040.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0009.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0120.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0177.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0183.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0148.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0109.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0143.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0229.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0037.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0018.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0235.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0201.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0078.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0023.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0142.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0191.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0075.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0001.png (deflated 38%)
# updating: content/generated_output/image_at_frame_0047.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0205.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0156.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0020.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0093.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0067.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0180.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0160.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0101.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0163.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0165.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0041.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0202.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0211.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0153.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0014.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0152.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0181.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0011.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0155.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0081.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0004.png (deflated 37%)
# updating: content/generated_output/image_at_frame_0048.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0050.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0188.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0187.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0162.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0178.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0223.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0044.png (deflated 36%)
# updating: content/generated_output/image_at_frame_0217.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0173.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0216.png (deflated 35%)
# updating: content/generated_output/image_at_frame_0132.png (deflated 35%)
